# %% [markdown]
# # insert_dws_campaign_cost_prd_d_inc
#
# - Name: insert_dws_sale_customer_prd_d_inc
# - Description: insert data to dws_sale_customer_prd_d_inc. Complete sales table - for further understanding of product_id, customer_id, stores.
# - Data modeling reference: https://docs.google.com/spreadsheets/d/1FlbiZEBue2SCAUo1WOkdtX5WbEDyDrZ9B2uiZUSiRio/edit?gid=596791655#gid=596791655
# - Target Table: dws_sale_customer_prd_d_inc
# - Source Table: dwd_sale_d_inc, dim_product_full, dim_store_full, dim_city_full, dim_customer_full
# - Created by: alvinxyzhang
# - Created Date: 2025-04-29
# - Version: v1.0

# %%
from google.cloud import bigquery
import datetime
import pandas as pd

# %% [markdown]
# ## Scheduled Task & Partition Table

# %%
# Construct a BigQuery client object.
client = bigquery.Client()

table_schema = [
        bigquery.SchemaField("date", "DATE"),
        bigquery.SchemaField("product_id", "INTEGER"),
        bigquery.SchemaField("purchase_type", "STRING"),
        bigquery.SchemaField("product_name", "STRING"),
        bigquery.SchemaField("category", "STRING"),
        bigquery.SchemaField("brand", "STRING"),
        bigquery.SchemaField("order_id", "INTEGER"),
        bigquery.SchemaField("number_of_items", "INTEGER"),
        bigquery.SchemaField("retail_price", "FLOAT"),
        bigquery.SchemaField("retail_cost", "FLOAT"),
        bigquery.SchemaField("total_price", "FLOAT"),
        bigquery.SchemaField("total_cost", "FLOAT"),
        bigquery.SchemaField("customer_id", "INTEGER"),
        bigquery.SchemaField("home_address", "STRING"),
        bigquery.SchemaField("longitude", "FLOAT"),
        bigquery.SchemaField("latitude", "FLOAT"),
        bigquery.SchemaField("email", "STRING"),
        bigquery.SchemaField("age", "INTEGER"),
        bigquery.SchemaField("gender", "STRING"),
        bigquery.SchemaField("account_created_date", "DATE"),
        bigquery.SchemaField("is_vip_membership", "INTEGER"),
        bigquery.SchemaField("family_size", "INTEGER"),
        bigquery.SchemaField("occupation", "STRING"),
        bigquery.SchemaField("annual_salary_estimate", "INTEGER"),
        bigquery.SchemaField("ad_group", "INTEGER"),
        bigquery.SchemaField("store_id", "INTEGER"),
        bigquery.SchemaField("store_name", "STRING"),
        bigquery.SchemaField("address", "STRING"),
        bigquery.SchemaField("city", "STRING"),
        bigquery.SchemaField("province", "STRING"),
        bigquery.SchemaField("lat", "FLOAT"),
        bigquery.SchemaField("long", "FLOAT"),
        bigquery.SchemaField("city_population", "INTEGER"),
        bigquery.SchemaField("city_lat", "FLOAT"),
        bigquery.SchemaField("city_long", "FLOAT")
    ]

insert_query = f"""
    SELECT `date`
        , sale_tbl.product_id
        , purchase_type
        , product_name
        , category
        , brand
        , order_id
        , SUM(number_of_items) number_of_items
        , AVG(retail_price) retail_price
        , AVG(cost) retail_cost
        , SUM(number_of_items * retail_price) total_price
        , SUM(number_of_items * cost) total_cost
        , sale_tbl.customer_id
        , home_address
        , customer_tbl.longitude AS customer_long
        , customer_tbl.latitude AS customer_lat
        , email
        , age
        , gender
        , account_created_date
        , is_vip_membership
        , family_size
        , occupation
        , annual_salary_estimate
        , ad_group
        , sale_tbl.store_id
        , store_name
        , store_tbl.address AS store_address
        , store_tbl.city
        , province
        , store_tbl.lat AS store_lat
        , store_tbl.long AS store_long
        , store_tbl.population AS city_population
        , city_tbl.lat AS city_lat
        , city_tbl.long AS city_long
    FROM
    (
      SELECT sale_date AS date
          , product_id
          , customer_id
          , store_id
          , order_id
          , purchase_type
          , SUM(number_of_items) number_of_items
      FROM `positive-karma-457703-i3.retail_dashboard.dwd_sale_d_inc`
      WHERE sale_date = @date_
      GROUP BY sale_date
          , product_id
          , customer_id
          , store_id
          , order_id
          , purchase_type
    ) AS sale_tbl
    LEFT JOIN `positive-karma-457703-i3.retail_dashboard.dim_product_full` AS prd_tbl
      ON sale_tbl.product_id = prd_tbl.product_id
    LEFT JOIN `positive-karma-457703-i3.retail_dashboard.dim_customer_full` AS customer_tbl
      ON sale_tbl.customer_id = customer_tbl.customer_id
    LEFT JOIN `positive-karma-457703-i3.retail_dashboard.dim_store_full` AS store_tbl
      ON sale_tbl.store_id = store_tbl.store_id
    LEFT JOIN `positive-karma-457703-i3.retail_dashboard.dim_city_full` AS city_tbl
      ON store_tbl.city = city_tbl.city
    GROUP BY `date`
          , sale_tbl.product_id
          , purchase_type
          , product_name
          , category
          , brand
          , order_id
          , sale_tbl.customer_id
          , home_address
          , customer_tbl.longitude
          , customer_tbl.latitude
          , email
          , age
          , gender
          , account_created_date
          , is_vip_membership
          , family_size
          , occupation
          , annual_salary_estimate
          , ad_group
          , sale_tbl.store_id
          , store_name
          , store_tbl.address
          , store_tbl.city
          , province
          , store_tbl.lat
          , store_tbl.long
          , store_tbl.population
          , city_tbl.lat
          , city_tbl.long
"""

# Step 1: Check if table exists
def check_table(table_id_, full_table_id_, schema_, partition_column_):
  try:
      table = client.get_table(full_table_id_)
      print(f"    Table {table_id_} already exists.")
  except:
      print(f"    Creating partitioned table {table_id_}...")

      table = bigquery.Table(full_table_id_, schema=schema_)
      table.time_partitioning = bigquery.TimePartitioning(
          type_=bigquery.TimePartitioningType.DAY,
          field=partition_col
      )

      table = client.create_table(table)
      print(f"Created partitioned table {full_table_id_}")

# Step 2: Insert Query
def insert_table(insert_query_, full_table_id_partition_, query_parameters_):
  job_config = bigquery.QueryJobConfig(
      destination = full_table_id_partition_,
      write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
      use_legacy_sql=False,
      query_parameters=query_parameters_
  )
  query_job_ = client.query(insert_query_, job_config=job_config)  # Make an API request.

  print('   Result:', query_job_.result())

  print('   Errors: ', query_job_.errors)

  return(query_job_)

# Step 3: Check Insert Rows
def check_insert_rows(partition_col_, full_table_id_, job_date_):
  query = f"""
      SELECT {partition_col_}, count(1) row_cnt
      FROM {full_table_id_}
      WHERE {partition_col_} = @date_
      GROUP BY {partition_col_}
  """
  job_config = bigquery.QueryJobConfig(
      query_parameters=[
          bigquery.ScalarQueryParameter("date_", "DATE", job_date_)
      ]
  )
  query_job = client.query_and_wait(query, job_config=job_config)

  row_cnt_df = query_job.to_dataframe()
  return(row_cnt_df)

# Main excution
dataset_id = 'retail_dashboard'
target_table = 'dws_sale_customer_prd_d_inc'
partition_col = 'date'
job_date = datetime.date(2024, 1, 1)

# Full table IDs
partition = job_date.strftime("%Y%m%d")
full_table_id = f"{client.project}.{dataset_id}.{target_table}"
full_table_id_partition = f"{client.project}.{dataset_id}.{target_table}${partition}"
query_parameters = [
        bigquery.ScalarQueryParameter("date_", "DATE", job_date)
    ]

print('- Execution: ', job_date, ' Partition: ', partition)
check_table(table_id_=target_table, full_table_id_=full_table_id, schema_ = table_schema, partition_column_ = partition_col)
query_job = insert_table(insert_query_ = insert_query, full_table_id_partition_ = full_table_id_partition, query_parameters_ = query_parameters)
print('- Finish writing to Partition ', partition)
row_cnt_df = check_insert_rows(partition_col_ = partition_col, full_table_id_ = full_table_id, job_date_ = job_date)
print('- Check: insert', str(row_cnt_df['row_cnt'].values[0]), 'rows.')
# Out:
# - Execution:  2024-01-01  Partition:  20240101
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1e7a0>
#    Errors:  None
# - Finish writing to Partition  20240101
# - Check: insert 3171 rows.

# %% [markdown]
# ## Iterate over Date

# %%
start_date = datetime.date(2024, 1, 1)
end_date = datetime.date(2025, 4, 25)
dataset_id = 'retail_dashboard'
target_table = 'dws_sale_customer_prd_d_inc'
partition_col = 'date'
full_table_id = f"{client.project}.{dataset_id}.{target_table}"

total_row_cnt_df = pd.DataFrame()

# iterate over range of dates
while (start_date <= end_date):
  job_date = start_date

  # Full table IDs
  partition = job_date.strftime("%Y%m%d")
  full_table_id_partition = f"{client.project}.{dataset_id}.{target_table}${partition}"
  query_parameters = [
        bigquery.ScalarQueryParameter("date_", "DATE", job_date)
    ]

  print('- Execution: ', job_date, ' Partition: ', partition)
  check_table(table_id_=target_table, full_table_id_=full_table_id, schema_ = table_schema, partition_column_ = partition_col)
  query_job = insert_table(insert_query_ = insert_query, full_table_id_partition_ = full_table_id_partition, query_parameters_ = query_parameters)
  print('- Finish writing to Partition ', partition)
  row_cnt_df = check_insert_rows(partition_col_ = partition_col, full_table_id_ = full_table_id, job_date_ = job_date)
  if row_cnt_df.shape[0] == 0:
    print('- Check: insert 0 rows.')
  else:
    print('- Check: insert', str(row_cnt_df['row_cnt'].values[0]), 'rows.')

  total_row_cnt_df = pd.concat([total_row_cnt_df, row_cnt_df], axis=0, join='outer', ignore_index=True)

  start_date += datetime.timedelta(days=1)
# Out:
# - Execution:  2024-01-01  Partition:  20240101
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908040>
#    Errors:  None
# - Finish writing to Partition  20240101
# - Check: insert 3171 rows.
# - Execution:  2024-01-02  Partition:  20240102
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909d50>
#    Errors:  None
# - Finish writing to Partition  20240102
# - Check: insert 3035 rows.
# - Execution:  2024-01-03  Partition:  20240103
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a1583a0>
#    Errors:  None
# - Finish writing to Partition  20240103
# - Check: insert 1817 rows.
# - Execution:  2024-01-04  Partition:  20240104
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909cf0>
#    Errors:  None
# - Finish writing to Partition  20240104
# - Check: insert 3636 rows.
# - Execution:  2024-01-05  Partition:  20240105
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908040>
#    Errors:  None
# - Finish writing to Partition  20240105
# - Check: insert 3811 rows.
# - Execution:  2024-01-06  Partition:  20240106
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1e950>
#    Errors:  None
# - Finish writing to Partition  20240106
# - Check: insert 9406 rows.
# - Execution:  2024-01-07  Partition:  20240107
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f7f0>
#    Errors:  None
# - Finish writing to Partition  20240107
# - Check: insert 14918 rows.
# - Execution:  2024-01-08  Partition:  20240108
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f7f0>
#    Errors:  None
# - Finish writing to Partition  20240108
# - Check: insert 3077 rows.
# - Execution:  2024-01-09  Partition:  20240109
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908160>
#    Errors:  None
# - Finish writing to Partition  20240109
# - Check: insert 4382 rows.
# - Execution:  2024-01-10  Partition:  20240110
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e89f00>
#    Errors:  None
# - Finish writing to Partition  20240110
# - Check: insert 3286 rows.
# - Execution:  2024-01-11  Partition:  20240111
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f700>
#    Errors:  None
# - Finish writing to Partition  20240111
# - Check: insert 3332 rows.
# - Execution:  2024-01-12  Partition:  20240112
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1e6e0>
#    Errors:  None
# - Finish writing to Partition  20240112
# - Check: insert 2963 rows.
# - Execution:  2024-01-13  Partition:  20240113
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889083a0>
#    Errors:  None
# - Finish writing to Partition  20240113
# - Check: insert 12094 rows.
# - Execution:  2024-01-14  Partition:  20240114
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b820>
#    Errors:  None
# - Finish writing to Partition  20240114
# - Check: insert 6659 rows.
# - Execution:  2024-01-15  Partition:  20240115
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1df90>
#    Errors:  None
# - Finish writing to Partition  20240115
# - Check: insert 2177 rows.
# - Execution:  2024-01-16  Partition:  20240116
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909930>
#    Errors:  None
# - Finish writing to Partition  20240116
# - Check: insert 2988 rows.
# - Execution:  2024-01-17  Partition:  20240117
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e8b5b0>
#    Errors:  None
# - Finish writing to Partition  20240117
# - Check: insert 3588 rows.
# - Execution:  2024-01-18  Partition:  20240118
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1dd20>
#    Errors:  None
# - Finish writing to Partition  20240118
# - Check: insert 3375 rows.
# - Execution:  2024-01-19  Partition:  20240119
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889083a0>
#    Errors:  None
# - Finish writing to Partition  20240119
# - Check: insert 2487 rows.
# - Execution:  2024-01-20  Partition:  20240120
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889099c0>
#    Errors:  None
# - Finish writing to Partition  20240120
# - Check: insert 12619 rows.
# - Execution:  2024-01-21  Partition:  20240121
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bffa0>
#    Errors:  None
# - Finish writing to Partition  20240121
# - Check: insert 14986 rows.
# - Execution:  2024-01-22  Partition:  20240122
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bd0c0>
#    Errors:  None
# - Finish writing to Partition  20240122
# - Check: insert 2909 rows.
# - Execution:  2024-01-23  Partition:  20240123
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1dd20>
#    Errors:  None
# - Finish writing to Partition  20240123
# - Check: insert 3444 rows.
# - Execution:  2024-01-24  Partition:  20240124
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bdea0>
#    Errors:  None
# - Finish writing to Partition  20240124
# - Check: insert 2381 rows.
# - Execution:  2024-01-25  Partition:  20240125
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bd6f0>
#    Errors:  None
# - Finish writing to Partition  20240125
# - Check: insert 4212 rows.
# - Execution:  2024-01-26  Partition:  20240126
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc070>
#    Errors:  None
# - Finish writing to Partition  20240126
# - Check: insert 1976 rows.
# - Execution:  2024-01-27  Partition:  20240127
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f6d0>
#    Errors:  None
# - Finish writing to Partition  20240127
# - Check: insert 15392 rows.
# - Execution:  2024-01-28  Partition:  20240128
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f7f0>
#    Errors:  None
# - Finish writing to Partition  20240128
# - Check: insert 14752 rows.
# - Execution:  2024-01-29  Partition:  20240129
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfcd0>
#    Errors:  None
# - Finish writing to Partition  20240129
# - Check: insert 2201 rows.
# - Execution:  2024-01-30  Partition:  20240130
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bdb10>
#    Errors:  None
# - Finish writing to Partition  20240130
# - Check: insert 3885 rows.
# - Execution:  2024-01-31  Partition:  20240131
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b880>
#    Errors:  None
# - Finish writing to Partition  20240131
# - Check: insert 2180 rows.
# - Execution:  2024-02-01  Partition:  20240201
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfc40>
#    Errors:  None
# - Finish writing to Partition  20240201
# - Check: insert 2188 rows.
# - Execution:  2024-02-02  Partition:  20240202
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33d810>
#    Errors:  None
# - Finish writing to Partition  20240202
# - Check: insert 4209 rows.
# - Execution:  2024-02-03  Partition:  20240203
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a1580d0>
#    Errors:  None
# - Finish writing to Partition  20240203
# - Check: insert 17787 rows.
# - Execution:  2024-02-04  Partition:  20240204
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b9d0>
#    Errors:  None
# - Finish writing to Partition  20240204
# - Check: insert 9129 rows.
# - Execution:  2024-02-05  Partition:  20240205
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33cfa0>
#    Errors:  None
# - Finish writing to Partition  20240205
# - Check: insert 4233 rows.
# - Execution:  2024-02-06  Partition:  20240206
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889082e0>
#    Errors:  None
# - Finish writing to Partition  20240206
# - Check: insert 1763 rows.
# - Execution:  2024-02-07  Partition:  20240207
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a30e200>
#    Errors:  None
# - Finish writing to Partition  20240207
# - Check: insert 2668 rows.
# - Execution:  2024-02-08  Partition:  20240208
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890baf0>
#    Errors:  None
# - Finish writing to Partition  20240208
# - Check: insert 2857 rows.
# - Execution:  2024-02-09  Partition:  20240209
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15b820>
#    Errors:  None
# - Finish writing to Partition  20240209
# - Check: insert 3278 rows.
# - Execution:  2024-02-10  Partition:  20240210
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1c100>
#    Errors:  None
# - Finish writing to Partition  20240210
# - Check: insert 7902 rows.
# - Execution:  2024-02-11  Partition:  20240211
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1e5f0>
#    Errors:  None
# - Finish writing to Partition  20240211
# - Check: insert 7336 rows.
# - Execution:  2024-02-12  Partition:  20240212
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909e10>
#    Errors:  None
# - Finish writing to Partition  20240212
# - Check: insert 4111 rows.
# - Execution:  2024-02-13  Partition:  20240213
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b8e2f0>
#    Errors:  None
# - Finish writing to Partition  20240213
# - Check: insert 4073 rows.
# - Execution:  2024-02-14  Partition:  20240214
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f040>
#    Errors:  None
# - Finish writing to Partition  20240214
# - Check: insert 2574 rows.
# - Execution:  2024-02-15  Partition:  20240215
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b8e2f0>
#    Errors:  None
# - Finish writing to Partition  20240215
# - Check: insert 3689 rows.
# - Execution:  2024-02-16  Partition:  20240216
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc130>
#    Errors:  None
# - Finish writing to Partition  20240216
# - Check: insert 2228 rows.
# - Execution:  2024-02-17  Partition:  20240217
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b8d570>
#    Errors:  None
# - Finish writing to Partition  20240217
# - Check: insert 17767 rows.
# - Execution:  2024-02-18  Partition:  20240218
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bd000>
#    Errors:  None
# - Finish writing to Partition  20240218
# - Check: insert 13881 rows.
# - Execution:  2024-02-19  Partition:  20240219
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc460>
#    Errors:  None
# - Finish writing to Partition  20240219
# - Check: insert 2505 rows.
# - Execution:  2024-02-20  Partition:  20240220
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc730>
#    Errors:  None
# - Finish writing to Partition  20240220
# - Check: insert 4255 rows.
# - Execution:  2024-02-21  Partition:  20240221
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf0a0>
#    Errors:  None
# - Finish writing to Partition  20240221
# - Check: insert 4284 rows.
# - Execution:  2024-02-22  Partition:  20240222
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bea40>
#    Errors:  None
# - Finish writing to Partition  20240222
# - Check: insert 1837 rows.
# - Execution:  2024-02-23  Partition:  20240223
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf580>
#    Errors:  None
# - Finish writing to Partition  20240223
# - Check: insert 2824 rows.
# - Execution:  2024-02-24  Partition:  20240224
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1c160>
#    Errors:  None
# - Finish writing to Partition  20240224
# - Check: insert 6146 rows.
# - Execution:  2024-02-25  Partition:  20240225
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bd870>
#    Errors:  None
# - Finish writing to Partition  20240225
# - Check: insert 19303 rows.
# - Execution:  2024-02-26  Partition:  20240226
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bff10>
#    Errors:  None
# - Finish writing to Partition  20240226
# - Check: insert 2622 rows.
# - Execution:  2024-02-27  Partition:  20240227
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfd30>
#    Errors:  None
# - Finish writing to Partition  20240227
# - Check: insert 4010 rows.
# - Execution:  2024-02-28  Partition:  20240228
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bea40>
#    Errors:  None
# - Finish writing to Partition  20240228
# - Check: insert 3968 rows.
# - Execution:  2024-02-29  Partition:  20240229
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a158880>
#    Errors:  None
# - Finish writing to Partition  20240229
# - Check: insert 3967 rows.
# - Execution:  2024-03-01  Partition:  20240301
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bcc10>
#    Errors:  None
# - Finish writing to Partition  20240301
# - Check: insert 2988 rows.
# - Execution:  2024-03-02  Partition:  20240302
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf3d0>
#    Errors:  None
# - Finish writing to Partition  20240302
# - Check: insert 10830 rows.
# - Execution:  2024-03-03  Partition:  20240303
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588964ca0>
#    Errors:  None
# - Finish writing to Partition  20240303
# - Check: insert 20329 rows.
# - Execution:  2024-03-04  Partition:  20240304
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc4c0>
#    Errors:  None
# - Finish writing to Partition  20240304
# - Check: insert 4445 rows.
# - Execution:  2024-03-05  Partition:  20240305
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889669b0>
#    Errors:  None
# - Finish writing to Partition  20240305
# - Check: insert 2150 rows.
# - Execution:  2024-03-06  Partition:  20240306
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889650f0>
#    Errors:  None
# - Finish writing to Partition  20240306
# - Check: insert 2455 rows.
# - Execution:  2024-03-07  Partition:  20240307
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890a6b0>
#    Errors:  None
# - Finish writing to Partition  20240307
# - Check: insert 2083 rows.
# - Execution:  2024-03-08  Partition:  20240308
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967c40>
#    Errors:  None
# - Finish writing to Partition  20240308
# - Check: insert 2478 rows.
# - Execution:  2024-03-09  Partition:  20240309
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967c40>
#    Errors:  None
# - Finish writing to Partition  20240309
# - Check: insert 9707 rows.
# - Execution:  2024-03-10  Partition:  20240310
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bcc10>
#    Errors:  None
# - Finish writing to Partition  20240310
# - Check: insert 12238 rows.
# - Execution:  2024-03-11  Partition:  20240311
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfd00>
#    Errors:  None
# - Finish writing to Partition  20240311
# - Check: insert 2666 rows.
# - Execution:  2024-03-12  Partition:  20240312
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc460>
#    Errors:  None
# - Finish writing to Partition  20240312
# - Check: insert 3216 rows.
# - Execution:  2024-03-13  Partition:  20240313
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf070>
#    Errors:  None
# - Finish writing to Partition  20240313
# - Check: insert 3626 rows.
# - Execution:  2024-03-14  Partition:  20240314
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc550>
#    Errors:  None
# - Finish writing to Partition  20240314
# - Check: insert 4356 rows.
# - Execution:  2024-03-15  Partition:  20240315
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1df30>
#    Errors:  None
# - Finish writing to Partition  20240315
# - Check: insert 2219 rows.
# - Execution:  2024-03-16  Partition:  20240316
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f430>
#    Errors:  None
# - Finish writing to Partition  20240316
# - Check: insert 10877 rows.
# - Execution:  2024-03-17  Partition:  20240317
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc4f0>
#    Errors:  None
# - Finish writing to Partition  20240317
# - Check: insert 7536 rows.
# - Execution:  2024-03-18  Partition:  20240318
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bdb10>
#    Errors:  None
# - Finish writing to Partition  20240318
# - Check: insert 2477 rows.
# - Execution:  2024-03-19  Partition:  20240319
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15bee0>
#    Errors:  None
# - Finish writing to Partition  20240319
# - Check: insert 2779 rows.
# - Execution:  2024-03-20  Partition:  20240320
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bdb10>
#    Errors:  None
# - Finish writing to Partition  20240320
# - Check: insert 1979 rows.
# - Execution:  2024-03-21  Partition:  20240321
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f6d0>
#    Errors:  None
# - Finish writing to Partition  20240321
# - Check: insert 4067 rows.
# - Execution:  2024-03-22  Partition:  20240322
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15bee0>
#    Errors:  None
# - Finish writing to Partition  20240322
# - Check: insert 1906 rows.
# - Execution:  2024-03-23  Partition:  20240323
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfd90>
#    Errors:  None
# - Finish writing to Partition  20240323
# - Check: insert 17774 rows.
# - Execution:  2024-03-24  Partition:  20240324
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bde40>
#    Errors:  None
# - Finish writing to Partition  20240324
# - Check: insert 17505 rows.
# - Execution:  2024-03-25  Partition:  20240325
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b640>
#    Errors:  None
# - Finish writing to Partition  20240325
# - Check: insert 2878 rows.
# - Execution:  2024-03-26  Partition:  20240326
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1c130>
#    Errors:  None
# - Finish writing to Partition  20240326
# - Check: insert 2611 rows.
# - Execution:  2024-03-27  Partition:  20240327
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890ba90>
#    Errors:  None
# - Finish writing to Partition  20240327
# - Check: insert 2285 rows.
# - Execution:  2024-03-28  Partition:  20240328
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bcb80>
#    Errors:  None
# - Finish writing to Partition  20240328
# - Check: insert 2689 rows.
# - Execution:  2024-03-29  Partition:  20240329
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33e050>
#    Errors:  None
# - Finish writing to Partition  20240329
# - Check: insert 10064 rows.
# - Execution:  2024-03-30  Partition:  20240330
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909270>
#    Errors:  None
# - Finish writing to Partition  20240330
# - Check: insert 12123 rows.
# - Execution:  2024-03-31  Partition:  20240331
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909900>
#    Errors:  None
# - Finish writing to Partition  20240331
# - Check: insert 17873 rows.
# - Execution:  2024-04-01  Partition:  20240401
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909b10>
#    Errors:  None
# - Finish writing to Partition  20240401
# - Check: insert 3797 rows.
# - Execution:  2024-04-02  Partition:  20240402
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908340>
#    Errors:  None
# - Finish writing to Partition  20240402
# - Check: insert 2512 rows.
# - Execution:  2024-04-03  Partition:  20240403
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f0d0>
#    Errors:  None
# - Finish writing to Partition  20240403
# - Check: insert 1760 rows.
# - Execution:  2024-04-04  Partition:  20240404
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfd00>
#    Errors:  None
# - Finish writing to Partition  20240404
# - Check: insert 1981 rows.
# - Execution:  2024-04-05  Partition:  20240405
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33e050>
#    Errors:  None
# - Finish writing to Partition  20240405
# - Check: insert 1888 rows.
# - Execution:  2024-04-06  Partition:  20240406
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfb50>
#    Errors:  None
# - Finish writing to Partition  20240406
# - Check: insert 12120 rows.
# - Execution:  2024-04-07  Partition:  20240407
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf430>
#    Errors:  None
# - Finish writing to Partition  20240407
# - Check: insert 10455 rows.
# - Execution:  2024-04-08  Partition:  20240408
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33c3a0>
#    Errors:  None
# - Finish writing to Partition  20240408
# - Check: insert 4386 rows.
# - Execution:  2024-04-09  Partition:  20240409
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bce80>
#    Errors:  None
# - Finish writing to Partition  20240409
# - Check: insert 4253 rows.
# - Execution:  2024-04-10  Partition:  20240410
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967f40>
#    Errors:  None
# - Finish writing to Partition  20240410
# - Check: insert 4072 rows.
# - Execution:  2024-04-11  Partition:  20240411
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889656f0>
#    Errors:  None
# - Finish writing to Partition  20240411
# - Check: insert 3730 rows.
# - Execution:  2024-04-12  Partition:  20240412
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33de10>
#    Errors:  None
# - Finish writing to Partition  20240412
# - Check: insert 4370 rows.
# - Execution:  2024-04-13  Partition:  20240413
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965db0>
#    Errors:  None
# - Finish writing to Partition  20240413
# - Check: insert 17070 rows.
# - Execution:  2024-04-14  Partition:  20240414
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf3d0>
#    Errors:  None
# - Finish writing to Partition  20240414
# - Check: insert 15786 rows.
# - Execution:  2024-04-15  Partition:  20240415
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889081c0>
#    Errors:  None
# - Finish writing to Partition  20240415
# - Check: insert 4061 rows.
# - Execution:  2024-04-16  Partition:  20240416
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908490>
#    Errors:  None
# - Finish writing to Partition  20240416
# - Check: insert 2051 rows.
# - Execution:  2024-04-17  Partition:  20240417
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890a6b0>
#    Errors:  None
# - Finish writing to Partition  20240417
# - Check: insert 1940 rows.
# - Execution:  2024-04-18  Partition:  20240418
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e8b940>
#    Errors:  None
# - Finish writing to Partition  20240418
# - Check: insert 1776 rows.
# - Execution:  2024-04-19  Partition:  20240419
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33de10>
#    Errors:  None
# - Finish writing to Partition  20240419
# - Check: insert 2568 rows.
# - Execution:  2024-04-20  Partition:  20240420
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909b10>
#    Errors:  None
# - Finish writing to Partition  20240420
# - Check: insert 16974 rows.
# - Execution:  2024-04-21  Partition:  20240421
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909b40>
#    Errors:  None
# - Finish writing to Partition  20240421
# - Check: insert 17254 rows.
# - Execution:  2024-04-22  Partition:  20240422
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b610>
#    Errors:  None
# - Finish writing to Partition  20240422
# - Check: insert 3355 rows.
# - Execution:  2024-04-23  Partition:  20240423
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f040>
#    Errors:  None
# - Finish writing to Partition  20240423
# - Check: insert 3145 rows.
# - Execution:  2024-04-24  Partition:  20240424
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588f0a800>
#    Errors:  None
# - Finish writing to Partition  20240424
# - Check: insert 2775 rows.
# - Execution:  2024-04-25  Partition:  20240425
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588909990>
#    Errors:  None
# - Finish writing to Partition  20240425
# - Check: insert 2553 rows.
# - Execution:  2024-04-26  Partition:  20240426
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890b9d0>
#    Errors:  None
# - Finish writing to Partition  20240426
# - Check: insert 3887 rows.
# - Execution:  2024-04-27  Partition:  20240427
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85cd9fa380>
#    Errors:  None
# - Finish writing to Partition  20240427
# - Check: insert 18143 rows.
# - Execution:  2024-04-28  Partition:  20240428
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf820>
#    Errors:  None
# - Finish writing to Partition  20240428
# - Check: insert 10523 rows.
# - Execution:  2024-04-29  Partition:  20240429
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588f094b0>
#    Errors:  None
# - Finish writing to Partition  20240429
# - Check: insert 4445 rows.
# - Execution:  2024-04-30  Partition:  20240430
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc1c0>
#    Errors:  None
# - Finish writing to Partition  20240430
# - Check: insert 2506 rows.
# - Execution:  2024-05-01  Partition:  20240501
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1f100>
#    Errors:  None
# - Finish writing to Partition  20240501
# - Check: insert 1907 rows.
# - Execution:  2024-05-02  Partition:  20240502
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bda20>
#    Errors:  None
# - Finish writing to Partition  20240502
# - Check: insert 2491 rows.
# - Execution:  2024-05-03  Partition:  20240503
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965ea0>
#    Errors:  None
# - Finish writing to Partition  20240503
# - Check: insert 1826 rows.
# - Execution:  2024-05-04  Partition:  20240504
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bcb50>
#    Errors:  None
# - Finish writing to Partition  20240504
# - Check: insert 10660 rows.
# - Execution:  2024-05-05  Partition:  20240505
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588964cd0>
#    Errors:  None
# - Finish writing to Partition  20240505
# - Check: insert 6240 rows.
# - Execution:  2024-05-06  Partition:  20240506
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965030>
#    Errors:  None
# - Finish writing to Partition  20240506
# - Check: insert 4265 rows.
# - Execution:  2024-05-07  Partition:  20240507
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15bd00>
#    Errors:  None
# - Finish writing to Partition  20240507
# - Check: insert 2527 rows.
# - Execution:  2024-05-08  Partition:  20240508
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965330>
#    Errors:  None
# - Finish writing to Partition  20240508
# - Check: insert 2895 rows.
# - Execution:  2024-05-09  Partition:  20240509
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967820>
#    Errors:  None
# - Finish writing to Partition  20240509
# - Check: insert 2217 rows.
# - Execution:  2024-05-10  Partition:  20240510
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a30cac0>
#    Errors:  None
# - Finish writing to Partition  20240510
# - Check: insert 4336 rows.
# - Execution:  2024-05-11  Partition:  20240511
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967610>
#    Errors:  None
# - Finish writing to Partition  20240511
# - Check: insert 9053 rows.
# - Execution:  2024-05-12  Partition:  20240512
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bdd20>
#    Errors:  None
# - Finish writing to Partition  20240512
# - Check: insert 20284 rows.
# - Execution:  2024-05-13  Partition:  20240513
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85cd9fa380>
#    Errors:  None
# - Finish writing to Partition  20240513
# - Check: insert 3818 rows.
# - Execution:  2024-05-14  Partition:  20240514
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965990>
#    Errors:  None
# - Finish writing to Partition  20240514
# - Check: insert 3068 rows.
# - Execution:  2024-05-15  Partition:  20240515
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588966ec0>
#    Errors:  None
# - Finish writing to Partition  20240515
# - Check: insert 3012 rows.
# - Execution:  2024-05-16  Partition:  20240516
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967160>
#    Errors:  None
# - Finish writing to Partition  20240516
# - Check: insert 1845 rows.
# - Execution:  2024-05-17  Partition:  20240517
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967b20>
#    Errors:  None
# - Finish writing to Partition  20240517
# - Check: insert 4279 rows.
# - Execution:  2024-05-18  Partition:  20240518
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965e70>
#    Errors:  None
# - Finish writing to Partition  20240518
# - Check: insert 11440 rows.
# - Execution:  2024-05-19  Partition:  20240519
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967010>
#    Errors:  None
# - Finish writing to Partition  20240519
# - Check: insert 6731 rows.
# - Execution:  2024-05-20  Partition:  20240520
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965ab0>
#    Errors:  None
# - Finish writing to Partition  20240520
# - Check: insert 3725 rows.
# - Execution:  2024-05-21  Partition:  20240521
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889658d0>
#    Errors:  None
# - Finish writing to Partition  20240521
# - Check: insert 2766 rows.
# - Execution:  2024-05-22  Partition:  20240522
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588966ef0>
#    Errors:  None
# - Finish writing to Partition  20240522
# - Check: insert 4336 rows.
# - Execution:  2024-05-23  Partition:  20240523
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889670d0>
#    Errors:  None
# - Finish writing to Partition  20240523
# - Check: insert 2051 rows.
# - Execution:  2024-05-24  Partition:  20240524
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588966710>
#    Errors:  None
# - Finish writing to Partition  20240524
# - Check: insert 2047 rows.
# - Execution:  2024-05-25  Partition:  20240525
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588966f20>
#    Errors:  None
# - Finish writing to Partition  20240525
# - Check: insert 12264 rows.
# - Execution:  2024-05-26  Partition:  20240526
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967400>
#    Errors:  None
# - Finish writing to Partition  20240526
# - Check: insert 9064 rows.
# - Execution:  2024-05-27  Partition:  20240527
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965420>
#    Errors:  None
# - Finish writing to Partition  20240527
# - Check: insert 3147 rows.
# - Execution:  2024-05-28  Partition:  20240528
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588966560>
#    Errors:  None
# - Finish writing to Partition  20240528
# - Check: insert 4433 rows.
# - Execution:  2024-05-29  Partition:  20240529
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967190>
#    Errors:  None
# - Finish writing to Partition  20240529
# - Check: insert 3160 rows.
# - Execution:  2024-05-30  Partition:  20240530
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588967580>
#    Errors:  None
# - Finish writing to Partition  20240530
# - Check: insert 3849 rows.
# - Execution:  2024-05-31  Partition:  20240531
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588965420>
#    Errors:  None
# - Finish writing to Partition  20240531
# - Check: insert 4484 rows.
# - Execution:  2024-06-01  Partition:  20240601
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588f094b0>
#    Errors:  None
# - Finish writing to Partition  20240601
# - Check: insert 21565 rows.
# - Execution:  2024-06-02  Partition:  20240602
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfc10>
#    Errors:  None
# - Finish writing to Partition  20240602
# - Check: insert 21281 rows.
# - Execution:  2024-06-03  Partition:  20240603
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889659c0>
#    Errors:  None
# - Finish writing to Partition  20240603
# - Check: insert 2053 rows.
# - Execution:  2024-06-04  Partition:  20240604
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876be380>
#    Errors:  None
# - Finish writing to Partition  20240604
# - Check: insert 3858 rows.
# - Execution:  2024-06-05  Partition:  20240605
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bd0f0>
#    Errors:  None
# - Finish writing to Partition  20240605
# - Check: insert 1866 rows.
# - Execution:  2024-06-06  Partition:  20240606
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1c130>
#    Errors:  None
# - Finish writing to Partition  20240606
# - Check: insert 2269 rows.
# - Execution:  2024-06-07  Partition:  20240607
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bfc10>
#    Errors:  None
# - Finish writing to Partition  20240607
# - Check: insert 3551 rows.
# - Execution:  2024-06-08  Partition:  20240608
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e89ff0>
#    Errors:  None
# - Finish writing to Partition  20240608
# - Check: insert 11062 rows.
# - Execution:  2024-06-09  Partition:  20240609
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33cfa0>
#    Errors:  None
# - Finish writing to Partition  20240609
# - Check: insert 9706 rows.
# - Execution:  2024-06-10  Partition:  20240610
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a30e200>
#    Errors:  None
# - Finish writing to Partition  20240610
# - Check: insert 4169 rows.
# - Execution:  2024-06-11  Partition:  20240611
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33de10>
#    Errors:  None
# - Finish writing to Partition  20240611
# - Check: insert 2455 rows.
# - Execution:  2024-06-12  Partition:  20240612
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15b1f0>
#    Errors:  None
# - Finish writing to Partition  20240612
# - Check: insert 4362 rows.
# - Execution:  2024-06-13  Partition:  20240613
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a1580d0>
#    Errors:  None
# - Finish writing to Partition  20240613
# - Check: insert 3332 rows.
# - Execution:  2024-06-14  Partition:  20240614
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889099c0>
#    Errors:  None
# - Finish writing to Partition  20240614
# - Check: insert 4207 rows.
# - Execution:  2024-06-15  Partition:  20240615
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bf640>
#    Errors:  None
# - Finish writing to Partition  20240615
# - Check: insert 14735 rows.
# - Execution:  2024-06-16  Partition:  20240616
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890abc0>
#    Errors:  None
# - Finish writing to Partition  20240616
# - Check: insert 13250 rows.
# - Execution:  2024-06-17  Partition:  20240617
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33ceb0>
#    Errors:  None
# - Finish writing to Partition  20240617
# - Check: insert 3432 rows.
# - Execution:  2024-06-18  Partition:  20240618
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e8bbe0>
#    Errors:  None
# - Finish writing to Partition  20240618
# - Check: insert 4145 rows.
# - Execution:  2024-06-19  Partition:  20240619
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bef20>
#    Errors:  None
# - Finish writing to Partition  20240619
# - Check: insert 2190 rows.
# - Execution:  2024-06-20  Partition:  20240620
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bcc10>
#    Errors:  None
# - Finish writing to Partition  20240620
# - Check: insert 1929 rows.
# - Execution:  2024-06-21  Partition:  20240621
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889379d0>
#    Errors:  None
# - Finish writing to Partition  20240621
# - Check: insert 2452 rows.
# - Execution:  2024-06-22  Partition:  20240622
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588937550>
#    Errors:  None
# - Finish writing to Partition  20240622
# - Check: insert 13020 rows.
# - Execution:  2024-06-23  Partition:  20240623
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33ceb0>
#    Errors:  None
# - Finish writing to Partition  20240623
# - Check: insert 11705 rows.
# - Execution:  2024-06-24  Partition:  20240624
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889376a0>
#    Errors:  None
# - Finish writing to Partition  20240624
# - Check: insert 3002 rows.
# - Execution:  2024-06-25  Partition:  20240625
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588935720>
#    Errors:  None
# - Finish writing to Partition  20240625
# - Check: insert 3252 rows.
# - Execution:  2024-06-26  Partition:  20240626
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bef20>
#    Errors:  None
# - Finish writing to Partition  20240626
# - Check: insert 1966 rows.
# - Execution:  2024-06-27  Partition:  20240627
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889342e0>
#    Errors:  None
# - Finish writing to Partition  20240627
# - Check: insert 2285 rows.
# - Execution:  2024-06-28  Partition:  20240628
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588934f40>
#    Errors:  None
# - Finish writing to Partition  20240628
# - Check: insert 3842 rows.
# - Execution:  2024-06-29  Partition:  20240629
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a15baf0>
#    Errors:  None
# - Finish writing to Partition  20240629
# - Check: insert 13119 rows.
# - Execution:  2024-06-30  Partition:  20240630
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b1ea10>
#    Errors:  None
# - Finish writing to Partition  20240630
# - Check: insert 17221 rows.
# - Execution:  2024-07-01  Partition:  20240701
# ...
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588937460>
#    Errors:  None
# - Finish writing to Partition  20250224
# - Check: insert 4347 rows.
# - Execution:  2025-02-25  Partition:  20250225
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e89f00>
#    Errors:  None
# - Finish writing to Partition  20250225
# - Check: insert 3022 rows.
# - Execution:  2025-02-26  Partition:  20250226
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588f09c90>
#    Errors:  None
# - Finish writing to Partition  20250226
# - Check: insert 4269 rows.
# - Execution:  2025-02-27  Partition:  20250227
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85876bc670>
#    Errors:  None
# - Finish writing to Partition  20250227
# - Check: insert 1928 rows.
# - Execution:  2025-02-28  Partition:  20250228
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588b3ee30>
#    Errors:  None
# - Finish writing to Partition  20250228
# - Check: insert 3990 rows.
# - Execution:  2025-03-01  Partition:  20250301
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890ab30>
#    Errors:  None
# - Finish writing to Partition  20250301
# - Check: insert 8107 rows.
# - Execution:  2025-03-02  Partition:  20250302
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588937730>
#    Errors:  None
# - Finish writing to Partition  20250302
# - Check: insert 6424 rows.
# - Execution:  2025-03-03  Partition:  20250303
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a1580d0>
#    Errors:  None
# - Finish writing to Partition  20250303
# - Check: insert 3175 rows.
# - Execution:  2025-03-04  Partition:  20250304
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588908310>
#    Errors:  None
# - Finish writing to Partition  20250304
# - Check: insert 2830 rows.
# - Execution:  2025-03-05  Partition:  20250305
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebefe0>
#    Errors:  None
# - Finish writing to Partition  20250305
# - Check: insert 3560 rows.
# - Execution:  2025-03-06  Partition:  20250306
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebed10>
#    Errors:  None
# - Finish writing to Partition  20250306
# - Check: insert 3170 rows.
# - Execution:  2025-03-07  Partition:  20250307
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588eeb670>
#    Errors:  None
# - Finish writing to Partition  20250307
# - Check: insert 3431 rows.
# - Execution:  2025-03-08  Partition:  20250308
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889368c0>
#    Errors:  None
# - Finish writing to Partition  20250308
# - Check: insert 10994 rows.
# - Execution:  2025-03-09  Partition:  20250309
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe740>
#    Errors:  None
# - Finish writing to Partition  20250309
# - Check: insert 10160 rows.
# - Execution:  2025-03-10  Partition:  20250310
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf0d0>
#    Errors:  None
# - Finish writing to Partition  20250310
# - Check: insert 2712 rows.
# - Execution:  2025-03-11  Partition:  20250311
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebc0d0>
#    Errors:  None
# - Finish writing to Partition  20250311
# - Check: insert 1923 rows.
# - Execution:  2025-03-12  Partition:  20250312
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebde10>
#    Errors:  None
# - Finish writing to Partition  20250312
# - Check: insert 2703 rows.
# - Execution:  2025-03-13  Partition:  20250313
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e89660>
#    Errors:  None
# - Finish writing to Partition  20250313
# - Check: insert 2736 rows.
# - Execution:  2025-03-14  Partition:  20250314
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebee90>
#    Errors:  None
# - Finish writing to Partition  20250314
# - Check: insert 2594 rows.
# - Execution:  2025-03-15  Partition:  20250315
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe050>
#    Errors:  None
# - Finish writing to Partition  20250315
# - Check: insert 16360 rows.
# - Execution:  2025-03-16  Partition:  20250316
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe980>
#    Errors:  None
# - Finish writing to Partition  20250316
# - Check: insert 15104 rows.
# - Execution:  2025-03-17  Partition:  20250317
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588e8bb50>
#    Errors:  None
# - Finish writing to Partition  20250317
# - Check: insert 3884 rows.
# - Execution:  2025-03-18  Partition:  20250318
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588937520>
#    Errors:  None
# - Finish writing to Partition  20250318
# - Check: insert 4131 rows.
# - Execution:  2025-03-19  Partition:  20250319
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889664a0>
#    Errors:  None
# - Finish writing to Partition  20250319
# - Check: insert 3801 rows.
# - Execution:  2025-03-20  Partition:  20250320
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588d8ffd0>
#    Errors:  None
# - Finish writing to Partition  20250320
# - Check: insert 3783 rows.
# - Execution:  2025-03-21  Partition:  20250321
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33d810>
#    Errors:  None
# - Finish writing to Partition  20250321
# - Check: insert 3274 rows.
# - Execution:  2025-03-22  Partition:  20250322
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858890ab60>
#    Errors:  None
# - Finish writing to Partition  20250322
# - Check: insert 7274 rows.
# - Execution:  2025-03-23  Partition:  20250323
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889654e0>
#    Errors:  None
# - Finish writing to Partition  20250323
# - Check: insert 12004 rows.
# - Execution:  2025-03-24  Partition:  20250324
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588935d80>
#    Errors:  None
# - Finish writing to Partition  20250324
# - Check: insert 3530 rows.
# - Execution:  2025-03-25  Partition:  20250325
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588935900>
#    Errors:  None
# - Finish writing to Partition  20250325
# - Check: insert 3896 rows.
# - Execution:  2025-03-26  Partition:  20250326
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f858a33d810>
#    Errors:  None
# - Finish writing to Partition  20250326
# - Check: insert 3559 rows.
# - Execution:  2025-03-27  Partition:  20250327
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588d8efe0>
#    Errors:  None
# - Finish writing to Partition  20250327
# - Check: insert 2663 rows.
# - Execution:  2025-03-28  Partition:  20250328
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588d8c580>
#    Errors:  None
# - Finish writing to Partition  20250328
# - Check: insert 2416 rows.
# - Execution:  2025-03-29  Partition:  20250329
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588d8f250>
#    Errors:  None
# - Finish writing to Partition  20250329
# - Check: insert 14326 rows.
# - Execution:  2025-03-30  Partition:  20250330
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588eea8f0>
#    Errors:  None
# - Finish writing to Partition  20250330
# - Check: insert 15153 rows.
# - Execution:  2025-03-31  Partition:  20250331
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebde10>
#    Errors:  None
# - Finish writing to Partition  20250331
# - Check: insert 3475 rows.
# - Execution:  2025-04-01  Partition:  20250401
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588d8ef80>
#    Errors:  None
# - Finish writing to Partition  20250401
# - Check: insert 2755 rows.
# - Execution:  2025-04-02  Partition:  20250402
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588935a20>
#    Errors:  None
# - Finish writing to Partition  20250402
# - Check: insert 3850 rows.
# - Execution:  2025-04-03  Partition:  20250403
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ee9960>
#    Errors:  None
# - Finish writing to Partition  20250403
# - Check: insert 2881 rows.
# - Execution:  2025-04-04  Partition:  20250404
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf850>
#    Errors:  None
# - Finish writing to Partition  20250404
# - Check: insert 3835 rows.
# - Execution:  2025-04-05  Partition:  20250405
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588eeaec0>
#    Errors:  None
# - Finish writing to Partition  20250405
# - Check: insert 12893 rows.
# - Execution:  2025-04-06  Partition:  20250406
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf7c0>
#    Errors:  None
# - Finish writing to Partition  20250406
# - Check: insert 12443 rows.
# - Execution:  2025-04-07  Partition:  20250407
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588eeb130>
#    Errors:  None
# - Finish writing to Partition  20250407
# - Check: insert 1988 rows.
# - Execution:  2025-04-08  Partition:  20250408
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f85889653f0>
#    Errors:  None
# - Finish writing to Partition  20250408
# - Check: insert 4440 rows.
# - Execution:  2025-04-09  Partition:  20250409
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe4a0>
#    Errors:  None
# - Finish writing to Partition  20250409
# - Check: insert 4363 rows.
# - Execution:  2025-04-10  Partition:  20250410
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebd000>
#    Errors:  None
# - Finish writing to Partition  20250410
# - Check: insert 2524 rows.
# - Execution:  2025-04-11  Partition:  20250411
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebd300>
#    Errors:  None
# - Finish writing to Partition  20250411
# - Check: insert 3879 rows.
# - Execution:  2025-04-12  Partition:  20250412
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf0d0>
#    Errors:  None
# - Finish writing to Partition  20250412
# - Check: insert 17482 rows.
# - Execution:  2025-04-13  Partition:  20250413
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebd930>
#    Errors:  None
# - Finish writing to Partition  20250413
# - Check: insert 6075 rows.
# - Execution:  2025-04-14  Partition:  20250414
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf160>
#    Errors:  None
# - Finish writing to Partition  20250414
# - Check: insert 2253 rows.
# - Execution:  2025-04-15  Partition:  20250415
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebcbe0>
#    Errors:  None
# - Finish writing to Partition  20250415
# - Check: insert 3858 rows.
# - Execution:  2025-04-16  Partition:  20250416
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebfe20>
#    Errors:  None
# - Finish writing to Partition  20250416
# - Check: insert 1835 rows.
# - Execution:  2025-04-17  Partition:  20250417
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf1f0>
#    Errors:  None
# - Finish writing to Partition  20250417
# - Check: insert 2084 rows.
# - Execution:  2025-04-18  Partition:  20250418
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe7a0>
#    Errors:  None
# - Finish writing to Partition  20250418
# - Check: insert 16277 rows.
# - Execution:  2025-04-19  Partition:  20250419
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebf0d0>
#    Errors:  None
# - Finish writing to Partition  20250419
# - Check: insert 12742 rows.
# - Execution:  2025-04-20  Partition:  20250420
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe2f0>
#    Errors:  None
# - Finish writing to Partition  20250420
# - Check: insert 12786 rows.
# - Execution:  2025-04-21  Partition:  20250421
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588eeb310>
#    Errors:  None
# - Finish writing to Partition  20250421
# - Check: insert 3405 rows.
# - Execution:  2025-04-22  Partition:  20250422
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe050>
#    Errors:  None
# - Finish writing to Partition  20250422
# - Check: insert 2932 rows.
# - Execution:  2025-04-23  Partition:  20250423
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebfc70>
#    Errors:  None
# - Finish writing to Partition  20250423
# - Check: insert 4449 rows.
# - Execution:  2025-04-24  Partition:  20250424
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe2c0>
#    Errors:  None
# - Finish writing to Partition  20250424
# - Check: insert 4412 rows.
# - Execution:  2025-04-25  Partition:  20250425
#     Table dws_sale_customer_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7f8588ebe050>
#    Errors:  None
# - Finish writing to Partition  20250425
# - Check: insert 2638 rows.

# %% [markdown]
# ### Insert Summary

# %%
total_row_cnt_df
# Out:
#            date  row_cnt
# 0    2024-01-01     3171
# 1    2024-01-02     3035
# 2    2024-01-03     1817
# 3    2024-01-04     3636
# 4    2024-01-05     3811
# ..          ...      ...
# 476  2025-04-21     3405
# 477  2025-04-22     2932
# 478  2025-04-23     4449
# 479  2025-04-24     4412
# 480  2025-04-25     2638
#
# [481 rows x 2 columns]
