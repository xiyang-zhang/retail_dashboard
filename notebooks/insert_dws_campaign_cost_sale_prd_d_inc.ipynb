# %% [markdown]
# # insert_dws_campaign_cost_sale_prd_d_inc
#
# - Name: dws_campaign_cost_sale_prd_d_inc
# - Description: Combine cost and sales for each product and campaign result
# - Data modeling reference: https://docs.google.com/spreadsheets/d/1FlbiZEBue2SCAUo1WOkdtX5WbEDyDrZ9B2uiZUSiRio/edit?gid=286240572#gid=286240572
# - Target Table: dws_campaign_cost_sales_prd_d_inc
# - Source Table: dws_sale_customer_prd_d_inc, dws_campaign_cost_prd_d_inc, dim_product_full
# - Created by: alvinxyzhang
# - Created Date: 2025-04-29
# - Version: v1.0

# %%
from google.cloud import bigquery
import datetime
import pandas as pd

# %% [markdown]
# ## Scheduled Task & Partition Table

# %%
# Construct a BigQuery client object.
client = bigquery.Client()

table_schema = [
        bigquery.SchemaField("date", "DATE"),
        bigquery.SchemaField("product_id", "INTEGER"),
        bigquery.SchemaField("purchase_type", "STRING"),
        bigquery.SchemaField("product_name", "STRING"),
        bigquery.SchemaField("category", "STRING"),
        bigquery.SchemaField("brand", "STRING"),
        bigquery.SchemaField("number_of_items", "INTEGER"),
        bigquery.SchemaField("retail_price", "FLOAT"),
        bigquery.SchemaField("retail_cost", "FLOAT"),
        bigquery.SchemaField("total_price", "FLOAT"),
        bigquery.SchemaField("total_cost", "FLOAT"),
        bigquery.SchemaField("campaign_id", "INTEGER"),
        bigquery.SchemaField("campaign_name", "STRING"),
        bigquery.SchemaField("campaign_type", "STRING"),
        bigquery.SchemaField("start_date", "DATE"),
        bigquery.SchemaField("end_date", "DATE"),
        bigquery.SchemaField("estimated_budget", "INTEGER"),
        bigquery.SchemaField("approved_budget", "INTEGER"),
        bigquery.SchemaField("real_spent_budget", "INTEGER"),
        bigquery.SchemaField("discount", "FLOAT"),
        bigquery.SchemaField("estimated_sales_increase", "FLOAT"),
        bigquery.SchemaField("count_product", "INTEGER"),
        bigquery.SchemaField("cost_in_store", "FLOAT"),
        bigquery.SchemaField("cost_flyer", "FLOAT"),
        bigquery.SchemaField("cost_community", "FLOAT"),
        bigquery.SchemaField("cost_loyalty", "FLOAT"),
        bigquery.SchemaField("cost_push", "FLOAT"),
        bigquery.SchemaField("cost_ad_total", "FLOAT"),
        bigquery.SchemaField("cost_ad_search", "FLOAT"),
        bigquery.SchemaField("cost_ad_display", "FLOAT"),
        bigquery.SchemaField("cost_ad_event", "FLOAT"),
        bigquery.SchemaField("cost_ad_retargeting", "FLOAT"),
        bigquery.SchemaField("cost_ad_email", "FLOAT"),
        bigquery.SchemaField("impressions_ad_total", "FLOAT"),
        bigquery.SchemaField("impressions_ad_search", "FLOAT"),
        bigquery.SchemaField("impressions_ad_display", "FLOAT"),
        bigquery.SchemaField("impressions_ad_event", "FLOAT"),
        bigquery.SchemaField("impressions_ad_retargeting", "FLOAT"),
        bigquery.SchemaField("impressions_ad_email", "FLOAT"),
        bigquery.SchemaField("clicks_ad_total", "FLOAT"),
        bigquery.SchemaField("clicks_ad_search", "FLOAT"),
        bigquery.SchemaField("clicks_ad_display", "FLOAT"),
        bigquery.SchemaField("clicks_ad_event", "FLOAT"),
        bigquery.SchemaField("clicks_ad_retargeting", "FLOAT"),
        bigquery.SchemaField("clicks_ad_email", "FLOAT"),
        bigquery.SchemaField("conversions_ad_total", "FLOAT"),
        bigquery.SchemaField("conversions_ad_search", "FLOAT"),
        bigquery.SchemaField("conversions_ad_display", "FLOAT"),
        bigquery.SchemaField("conversions_ad_event", "FLOAT"),
        bigquery.SchemaField("conversions_ad_retargeting", "FLOAT"),
        bigquery.SchemaField("conversions_ad_email", "FLOAT"),
        bigquery.SchemaField("retail_discount_price", "FLOAT"),
        bigquery.SchemaField("total_discount_price", "FLOAT")
    ]

insert_query = f"""
    WITH sale_tbl AS (
      SELECT `date`
          , product_id
          , purchase_type
          , product_name
          , category
          , brand
          , SUM(number_of_items) AS number_of_items
          , AVG(retail_price) AS retail_price
          , AVG(retail_cost) AS retail_cost
          , SUM(total_price) AS total_price
          , SUM(total_cost) AS total_cost
      FROM `positive-karma-457703-i3.retail_dashboard.dws_sale_customer_prd_d_inc`
      WHERE `date` = @date_
      GROUP BY `date`
          , product_id
          , purchase_type
          , product_name
          , category
          , brand
    ), campaign_tbl AS (
      SELECT `date`
          , product_id
          , campaign_id
          , campaign_name
          , campaign_type
          , start_date
          , end_date
          , estimated_budget
          , approved_budget
          , real_spent_budget
          , discount
          , estimated_sales_increase
          , count_product
          , SUM(cost_in_store) AS cost_in_store
          , SUM(cost_flyer) AS cost_flyer
          , SUM(cost_community) AS cost_community
          , SUM(cost_loyalty) AS cost_loyalty
          , SUM(cost_push) AS cost_push
          , SUM(cost_ad_total) AS cost_ad_total
          , SUM(cost_ad_search) AS cost_ad_search
          , SUM(cost_ad_display) AS cost_ad_display
          , SUM(cost_ad_event) AS cost_ad_event
          , SUM(cost_ad_retargeting) AS cost_ad_retargeting
          , SUM(cost_ad_email) AS cost_ad_email
          , SUM(impressions_ad_total) AS impressions_ad_total
          , SUM(impressions_ad_search) AS impressions_ad_search
          , SUM(impressions_ad_display) AS impressions_ad_display
          , SUM(impressions_ad_event) AS impressions_ad_event
          , SUM(impressions_ad_retargeting) AS impressions_ad_retargeting
          , SUM(impressions_ad_email) AS impressions_ad_email
          , SUM(clicks_ad_total) AS clicks_ad_total
          , SUM(clicks_ad_search) AS clicks_ad_search
          , SUM(clicks_ad_display) AS clicks_ad_display
          , SUM(clicks_ad_event) AS clicks_ad_event
          , SUM(clicks_ad_retargeting) AS clicks_ad_retargeting
          , SUM(clicks_ad_email) AS clicks_ad_email
          , SUM(conversions_ad_total) AS conversions_ad_total
          , SUM(conversions_ad_search) AS conversions_ad_search
          , SUM(conversions_ad_display) AS conversions_ad_display
          , SUM(conversions_ad_event) AS conversions_ad_event
          , SUM(conversions_ad_retargeting) AS conversions_ad_retargeting
          , SUM(conversions_ad_email) AS conversions_ad_email
      FROM `positive-karma-457703-i3.retail_dashboard.dws_campaign_cost_prd_d_inc`
      WHERE `date` = @date_
      GROUP BY `date`
            , product_id
            , campaign_id
            , campaign_name
            , campaign_type
            , start_date
            , end_date
            , estimated_budget
            , approved_budget
            , real_spent_budget
            , discount
            , estimated_sales_increase
            , count_product
      ORDER BY product_id
    )

    SELECT @date_ AS `date`
          , prd_tbl.product_id AS product_id
          , purchase_type
          , prd_tbl.product_name AS product_name
          , prd_tbl.category AS category
          , prd_tbl.brand AS brand
          , coalesce(number_of_items, 0) AS number_of_items
          , coalesce(sale_tbl.retail_price, prd_tbl.retail_price) AS retail_price
          , coalesce(sale_tbl.retail_cost, prd_tbl.cost) AS retail_cost
          , coalesce(total_price, 0) AS total_price
          , coalesce(total_cost, 0) AS total_cost
          , campaign_id
          , campaign_name
          , campaign_type
          , start_date
          , end_date
          , estimated_budget
          , approved_budget
          , real_spent_budget
          , discount
          , estimated_sales_increase
          , count_product
          , cost_in_store
          , cost_flyer
          , cost_community
          , cost_loyalty
          , cost_push
          , cost_ad_total
          , cost_ad_search
          , cost_ad_display
          , cost_ad_event
          , cost_ad_retargeting
          , cost_ad_email
          , impressions_ad_total
          , impressions_ad_search
          , impressions_ad_display
          , impressions_ad_event
          , impressions_ad_retargeting
          , impressions_ad_email
          , clicks_ad_total
          , clicks_ad_search
          , clicks_ad_display
          , clicks_ad_event
          , clicks_ad_retargeting
          , clicks_ad_email
          , conversions_ad_total
          , conversions_ad_search
          , conversions_ad_display
          , conversions_ad_event
          , conversions_ad_retargeting
          , conversions_ad_email
          , coalesce(sale_tbl.retail_price, prd_tbl.retail_price) * (1 - discount) AS retail_discount_price
          , coalesce(total_price, 0) * (1 - discount) AS total_discount_price
    FROM `positive-karma-457703-i3.retail_dashboard.dim_product_full` AS prd_tbl
    LEFT JOIN sale_tbl
      ON sale_tbl.product_id = prd_tbl.product_id
    LEFT JOIN campaign_tbl
      ON campaign_tbl.product_id = prd_tbl.product_id
    ORDER BY prd_tbl.product_id ASC
"""

# Step 1: Check if table exists
def check_table(table_id_, full_table_id_, schema_, partition_column_):
  try:
      table = client.get_table(full_table_id_)
      print(f"    Table {table_id_} already exists.")
  except:
      print(f"    Creating partitioned table {table_id_}...")

      table = bigquery.Table(full_table_id_, schema=schema_)
      table.time_partitioning = bigquery.TimePartitioning(
          type_=bigquery.TimePartitioningType.DAY,
          field=partition_col
      )

      table = client.create_table(table)
      print(f"Created partitioned table {full_table_id_}")

# Step 2: Insert Query
def insert_table(insert_query_, full_table_id_partition_, query_parameters_):
  job_config = bigquery.QueryJobConfig(
      destination = full_table_id_partition_,
      write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
      use_legacy_sql=False,
      query_parameters=query_parameters_
  )
  query_job_ = client.query(insert_query_, job_config=job_config)  # Make an API request.

  print('   Result:', query_job_.result())

  print('   Errors: ', query_job_.errors)

  return(query_job_)

# Step 3: Check Insert Rows
def check_insert_rows(partition_col_, full_table_id_, job_date_):
  query = f"""
      SELECT {partition_col_}, count(1) row_cnt
      FROM {full_table_id_}
      WHERE {partition_col_} = @date_
      GROUP BY {partition_col_}
  """
  job_config = bigquery.QueryJobConfig(
      query_parameters=[
          bigquery.ScalarQueryParameter("date_", "DATE", job_date_)
      ]
  )
  query_job = client.query_and_wait(query, job_config=job_config)

  row_cnt_df = query_job.to_dataframe()
  return(row_cnt_df)

# Main excution
dataset_id = 'retail_dashboard'
target_table = 'dws_campaign_cost_sale_prd_d_inc'
partition_col = 'date'
job_date = datetime.date(2024, 1, 1)

# Full table IDs
partition = job_date.strftime("%Y%m%d")
full_table_id = f"{client.project}.{dataset_id}.{target_table}"
full_table_id_partition = f"{client.project}.{dataset_id}.{target_table}${partition}"
query_parameters = [
        bigquery.ScalarQueryParameter("date_", "DATE", job_date)
    ]

print('- Execution: ', job_date, ' Partition: ', partition)
check_table(table_id_=target_table, full_table_id_=full_table_id, schema_ = table_schema, partition_column_ = partition_col)
query_job = insert_table(insert_query_ = insert_query, full_table_id_partition_ = full_table_id_partition, query_parameters_ = query_parameters)
print('- Finish writing to Partition ', partition)
row_cnt_df = check_insert_rows(partition_col_ = partition_col, full_table_id_ = full_table_id, job_date_ = job_date)
print('- Check: insert', str(row_cnt_df['row_cnt'].values[0]), 'rows.')
# Out:
# - Execution:  2024-01-01  Partition:  20240101
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e67850>
#    Errors:  None
# - Finish writing to Partition  20240101
# - Check: insert 2570 rows.

# %% [markdown]
# ## Iterate over Date

# %%
start_date = datetime.date(2024, 1, 5)
end_date = datetime.date(2025, 4, 25)
dataset_id = 'retail_dashboard'
target_table = 'dws_campaign_cost_sale_prd_d_inc'
partition_col = 'date'
full_table_id = f"{client.project}.{dataset_id}.{target_table}"

total_row_cnt_df = pd.DataFrame()

# iterate over range of dates
while (start_date <= end_date):
  job_date = start_date

  # Full table IDs
  partition = job_date.strftime("%Y%m%d")
  full_table_id_partition = f"{client.project}.{dataset_id}.{target_table}${partition}"
  query_parameters = [
        bigquery.ScalarQueryParameter("date_", "DATE", job_date)
    ]

  print('- Execution: ', job_date, ' Partition: ', partition)
  check_table(table_id_=target_table, full_table_id_=full_table_id, schema_ = table_schema, partition_column_ = partition_col)
  query_job = insert_table(insert_query_ = insert_query, full_table_id_partition_ = full_table_id_partition, query_parameters_ = query_parameters)
  print('- Finish writing to Partition ', partition)
  row_cnt_df = check_insert_rows(partition_col_ = partition_col, full_table_id_ = full_table_id, job_date_ = job_date)
  if row_cnt_df.shape[0] == 0:
    print('- Check: insert 0 rows.')
  else:
    print('- Check: insert', str(row_cnt_df['row_cnt'].values[0]), 'rows.')

  total_row_cnt_df = pd.concat([total_row_cnt_df, row_cnt_df], axis=0, join='outer', ignore_index=True)

  start_date += datetime.timedelta(days=1)
# Out:
# - Execution:  2024-01-05  Partition:  20240105
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fed7b0>
#    Errors:  None
# - Finish writing to Partition  20240105
# - Check: insert 2742 rows.
# - Execution:  2024-01-06  Partition:  20240106
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cae0e0>
#    Errors:  None
# - Finish writing to Partition  20240106
# - Check: insert 3622 rows.
# - Execution:  2024-01-07  Partition:  20240107
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d660>
#    Errors:  None
# - Finish writing to Partition  20240107
# - Check: insert 3891 rows.
# - Execution:  2024-01-08  Partition:  20240108
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cacf70>
#    Errors:  None
# - Finish writing to Partition  20240108
# - Check: insert 2581 rows.
# - Execution:  2024-01-09  Partition:  20240109
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cad7e0>
#    Errors:  None
# - Finish writing to Partition  20240109
# - Check: insert 2906 rows.
# - Execution:  2024-01-10  Partition:  20240110
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d4b0>
#    Errors:  None
# - Finish writing to Partition  20240110
# - Check: insert 2602 rows.
# - Execution:  2024-01-11  Partition:  20240111
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cac9d0>
#    Errors:  None
# - Finish writing to Partition  20240111
# - Check: insert 2655 rows.
# - Execution:  2024-01-12  Partition:  20240112
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d08790>
#    Errors:  None
# - Finish writing to Partition  20240112
# - Check: insert 2541 rows.
# - Execution:  2024-01-13  Partition:  20240113
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143f10>
#    Errors:  None
# - Finish writing to Partition  20240113
# - Check: insert 3818 rows.
# - Execution:  2024-01-14  Partition:  20240114
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d4b0>
#    Errors:  None
# - Finish writing to Partition  20240114
# - Check: insert 3302 rows.
# - Execution:  2024-01-15  Partition:  20240115
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0b2b0>
#    Errors:  None
# - Finish writing to Partition  20240115
# - Check: insert 2349 rows.
# - Execution:  2024-01-16  Partition:  20240116
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142c20>
#    Errors:  None
# - Finish writing to Partition  20240116
# - Check: insert 2559 rows.
# - Execution:  2024-01-17  Partition:  20240117
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fee680>
#    Errors:  None
# - Finish writing to Partition  20240117
# - Check: insert 2701 rows.
# - Execution:  2024-01-18  Partition:  20240118
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fef850>
#    Errors:  None
# - Finish writing to Partition  20240118
# - Check: insert 2638 rows.
# - Execution:  2024-01-19  Partition:  20240119
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142590>
#    Errors:  None
# - Finish writing to Partition  20240119
# - Check: insert 2426 rows.
# - Execution:  2024-01-20  Partition:  20240120
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141090>
#    Errors:  None
# - Finish writing to Partition  20240120
# - Check: insert 3825 rows.
# - Execution:  2024-01-21  Partition:  20240121
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739feea40>
#    Errors:  None
# - Finish writing to Partition  20240121
# - Check: insert 3895 rows.
# - Execution:  2024-01-22  Partition:  20240122
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca6e60>
#    Errors:  None
# - Finish writing to Partition  20240122
# - Check: insert 2551 rows.
# - Execution:  2024-01-23  Partition:  20240123
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143c10>
#    Errors:  None
# - Finish writing to Partition  20240123
# - Check: insert 2670 rows.
# - Execution:  2024-01-24  Partition:  20240124
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca49d0>
#    Errors:  None
# - Finish writing to Partition  20240124
# - Check: insert 2401 rows.
# - Execution:  2024-01-25  Partition:  20240125
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14e9b0>
#    Errors:  None
# - Finish writing to Partition  20240125
# - Check: insert 2853 rows.
# - Execution:  2024-01-26  Partition:  20240126
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0afe0>
#    Errors:  None
# - Finish writing to Partition  20240126
# - Check: insert 2309 rows.
# - Execution:  2024-01-27  Partition:  20240127
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0bf40>
#    Errors:  None
# - Finish writing to Partition  20240127
# - Check: insert 3907 rows.
# - Execution:  2024-01-28  Partition:  20240128
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739caca60>
#    Errors:  None
# - Finish writing to Partition  20240128
# - Check: insert 3911 rows.
# - Execution:  2024-01-29  Partition:  20240129
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14c940>
#    Errors:  None
# - Finish writing to Partition  20240129
# - Check: insert 2381 rows.
# - Execution:  2024-01-30  Partition:  20240130
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14e560>
#    Errors:  None
# - Finish writing to Partition  20240130
# - Check: insert 2749 rows.
# - Execution:  2024-01-31  Partition:  20240131
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c070>
#    Errors:  None
# - Finish writing to Partition  20240131
# - Check: insert 2346 rows.
# - Execution:  2024-02-01  Partition:  20240201
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14ea40>
#    Errors:  None
# - Finish writing to Partition  20240201
# - Check: insert 2375 rows.
# - Execution:  2024-02-02  Partition:  20240202
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cac8e0>
#    Errors:  None
# - Finish writing to Partition  20240202
# - Check: insert 2854 rows.
# - Execution:  2024-02-03  Partition:  20240203
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d870>
#    Errors:  None
# - Finish writing to Partition  20240203
# - Check: insert 3962 rows.
# - Execution:  2024-02-04  Partition:  20240204
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739caeaa0>
#    Errors:  None
# - Finish writing to Partition  20240204
# - Check: insert 3617 rows.
# - Execution:  2024-02-05  Partition:  20240205
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b485840>
#    Errors:  None
# - Finish writing to Partition  20240205
# - Check: insert 2864 rows.
# - Execution:  2024-02-06  Partition:  20240206
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14c6d0>
#    Errors:  None
# - Finish writing to Partition  20240206
# - Check: insert 2249 rows.
# - Execution:  2024-02-07  Partition:  20240207
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79476dca9d50>
#    Errors:  None
# - Finish writing to Partition  20240207
# - Check: insert 2479 rows.
# - Execution:  2024-02-08  Partition:  20240208
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0e620>
#    Errors:  None
# - Finish writing to Partition  20240208
# - Check: insert 2535 rows.
# - Execution:  2024-02-09  Partition:  20240209
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b485810>
#    Errors:  None
# - Finish writing to Partition  20240209
# - Check: insert 2634 rows.
# - Execution:  2024-02-10  Partition:  20240210
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14de70>
#    Errors:  None
# - Finish writing to Partition  20240210
# - Check: insert 3504 rows.
# - Execution:  2024-02-11  Partition:  20240211
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141ff0>
#    Errors:  None
# - Finish writing to Partition  20240211
# - Check: insert 3417 rows.
# - Execution:  2024-02-12  Partition:  20240212
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cac520>
#    Errors:  None
# - Finish writing to Partition  20240212
# - Check: insert 2808 rows.
# - Execution:  2024-02-13  Partition:  20240213
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79476dcaad70>
#    Errors:  None
# - Finish writing to Partition  20240213
# - Check: insert 2809 rows.
# - Execution:  2024-02-14  Partition:  20240214
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14dba0>
#    Errors:  None
# - Finish writing to Partition  20240214
# - Check: insert 2447 rows.
# - Execution:  2024-02-15  Partition:  20240215
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141a50>
#    Errors:  None
# - Finish writing to Partition  20240215
# - Check: insert 2734 rows.
# - Execution:  2024-02-16  Partition:  20240216
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14cc70>
#    Errors:  None
# - Finish writing to Partition  20240216
# - Check: insert 2358 rows.
# - Execution:  2024-02-17  Partition:  20240217
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e67430>
#    Errors:  None
# - Finish writing to Partition  20240217
# - Check: insert 3944 rows.
# - Execution:  2024-02-18  Partition:  20240218
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14cca0>
#    Errors:  None
# - Finish writing to Partition  20240218
# - Check: insert 3874 rows.
# - Execution:  2024-02-19  Partition:  20240219
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a140c40>
#    Errors:  None
# - Finish writing to Partition  20240219
# - Check: insert 2445 rows.
# - Execution:  2024-02-20  Partition:  20240220
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e66020>
#    Errors:  None
# - Finish writing to Partition  20240220
# - Check: insert 2831 rows.
# - Execution:  2024-02-21  Partition:  20240221
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14cca0>
#    Errors:  None
# - Finish writing to Partition  20240221
# - Check: insert 2867 rows.
# - Execution:  2024-02-22  Partition:  20240222
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28490>
#    Errors:  None
# - Finish writing to Partition  20240222
# - Check: insert 2278 rows.
# - Execution:  2024-02-23  Partition:  20240223
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e29f30>
#    Errors:  None
# - Finish writing to Partition  20240223
# - Check: insert 2505 rows.
# - Execution:  2024-02-24  Partition:  20240224
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e64910>
#    Errors:  None
# - Finish writing to Partition  20240224
# - Check: insert 3236 rows.
# - Execution:  2024-02-25  Partition:  20240225
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e653c0>
#    Errors:  None
# - Finish writing to Partition  20240225
# - Check: insert 3962 rows.
# - Execution:  2024-02-26  Partition:  20240226
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0dbd0>
#    Errors:  None
# - Finish writing to Partition  20240226
# - Check: insert 2478 rows.
# - Execution:  2024-02-27  Partition:  20240227
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28820>
#    Errors:  None
# - Finish writing to Partition  20240227
# - Check: insert 2799 rows.
# - Execution:  2024-02-28  Partition:  20240228
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b485840>
#    Errors:  None
# - Finish writing to Partition  20240228
# - Check: insert 2767 rows.
# - Execution:  2024-02-29  Partition:  20240229
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e64610>
#    Errors:  None
# - Finish writing to Partition  20240229
# - Check: insert 2821 rows.
# - Execution:  2024-03-01  Partition:  20240301
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e29db0>
#    Errors:  None
# - Finish writing to Partition  20240301
# - Check: insert 2538 rows.
# - Execution:  2024-03-02  Partition:  20240302
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1421d0>
#    Errors:  None
# - Finish writing to Partition  20240302
# - Check: insert 3742 rows.
# - Execution:  2024-03-03  Partition:  20240303
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142e00>
#    Errors:  None
# - Finish writing to Partition  20240303
# - Check: insert 3976 rows.
# - Execution:  2024-03-04  Partition:  20240304
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0b2b0>
#    Errors:  None
# - Finish writing to Partition  20240304
# - Check: insert 2923 rows.
# - Execution:  2024-03-05  Partition:  20240305
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142590>
#    Errors:  None
# - Finish writing to Partition  20240305
# - Check: insert 2330 rows.
# - Execution:  2024-03-06  Partition:  20240306
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1421d0>
#    Errors:  None
# - Finish writing to Partition  20240306
# - Check: insert 2430 rows.
# - Execution:  2024-03-07  Partition:  20240307
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d870>
#    Errors:  None
# - Finish writing to Partition  20240307
# - Check: insert 2310 rows.
# - Execution:  2024-03-08  Partition:  20240308
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1424a0>
#    Errors:  None
# - Finish writing to Partition  20240308
# - Check: insert 2418 rows.
# - Execution:  2024-03-09  Partition:  20240309
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cae080>
#    Errors:  None
# - Finish writing to Partition  20240309
# - Check: insert 3671 rows.
# - Execution:  2024-03-10  Partition:  20240310
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14ddb0>
#    Errors:  None
# - Finish writing to Partition  20240310
# - Check: insert 3804 rows.
# - Execution:  2024-03-11  Partition:  20240311
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142a70>
#    Errors:  None
# - Finish writing to Partition  20240311
# - Check: insert 2470 rows.
# - Execution:  2024-03-12  Partition:  20240312
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cae080>
#    Errors:  None
# - Finish writing to Partition  20240312
# - Check: insert 2599 rows.
# - Execution:  2024-03-13  Partition:  20240313
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca53f0>
#    Errors:  None
# - Finish writing to Partition  20240313
# - Check: insert 2695 rows.
# - Execution:  2024-03-14  Partition:  20240314
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e67dc0>
#    Errors:  None
# - Finish writing to Partition  20240314
# - Check: insert 2895 rows.
# - Execution:  2024-03-15  Partition:  20240315
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fed7b0>
#    Errors:  None
# - Finish writing to Partition  20240315
# - Check: insert 2380 rows.
# - Execution:  2024-03-16  Partition:  20240316
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e65f30>
#    Errors:  None
# - Finish writing to Partition  20240316
# - Check: insert 3747 rows.
# - Execution:  2024-03-17  Partition:  20240317
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143190>
#    Errors:  None
# - Finish writing to Partition  20240317
# - Check: insert 3434 rows.
# - Execution:  2024-03-18  Partition:  20240318
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a140310>
#    Errors:  None
# - Finish writing to Partition  20240318
# - Check: insert 2406 rows.
# - Execution:  2024-03-19  Partition:  20240319
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e67be0>
#    Errors:  None
# - Finish writing to Partition  20240319
# - Check: insert 2526 rows.
# - Execution:  2024-03-20  Partition:  20240320
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143040>
#    Errors:  None
# - Finish writing to Partition  20240320
# - Check: insert 2309 rows.
# - Execution:  2024-03-21  Partition:  20240321
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a140730>
#    Errors:  None
# - Finish writing to Partition  20240321
# - Check: insert 2817 rows.
# - Execution:  2024-03-22  Partition:  20240322
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e646d0>
#    Errors:  None
# - Finish writing to Partition  20240322
# - Check: insert 2289 rows.
# - Execution:  2024-03-23  Partition:  20240323
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a140160>
#    Errors:  None
# - Finish writing to Partition  20240323
# - Check: insert 3938 rows.
# - Execution:  2024-03-24  Partition:  20240324
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e65f30>
#    Errors:  None
# - Finish writing to Partition  20240324
# - Check: insert 3944 rows.
# - Execution:  2024-03-25  Partition:  20240325
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8ee0>
#    Errors:  None
# - Finish writing to Partition  20240325
# - Check: insert 2535 rows.
# - Execution:  2024-03-26  Partition:  20240326
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e65270>
#    Errors:  None
# - Finish writing to Partition  20240326
# - Check: insert 2444 rows.
# - Execution:  2024-03-27  Partition:  20240327
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8bb0>
#    Errors:  None
# - Finish writing to Partition  20240327
# - Check: insert 2370 rows.
# - Execution:  2024-03-28  Partition:  20240328
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14ddb0>
#    Errors:  None
# - Finish writing to Partition  20240328
# - Check: insert 2462 rows.
# - Execution:  2024-03-29  Partition:  20240329
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1404c0>
#    Errors:  None
# - Finish writing to Partition  20240329
# - Check: insert 3678 rows.
# - Execution:  2024-03-30  Partition:  20240330
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cae200>
#    Errors:  None
# - Finish writing to Partition  20240330
# - Check: insert 3814 rows.
# - Execution:  2024-03-31  Partition:  20240331
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28cd0>
#    Errors:  None
# - Finish writing to Partition  20240331
# - Check: insert 3958 rows.
# - Execution:  2024-04-01  Partition:  20240401
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142a70>
#    Errors:  None
# - Finish writing to Partition  20240401
# - Check: insert 2760 rows.
# - Execution:  2024-04-02  Partition:  20240402
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f9060>
#    Errors:  None
# - Finish writing to Partition  20240402
# - Check: insert 2408 rows.
# - Execution:  2024-04-03  Partition:  20240403
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28f70>
#    Errors:  None
# - Finish writing to Partition  20240403
# - Check: insert 2240 rows.
# - Execution:  2024-04-04  Partition:  20240404
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e65630>
#    Errors:  None
# - Finish writing to Partition  20240404
# - Check: insert 2300 rows.
# - Execution:  2024-04-05  Partition:  20240405
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142230>
#    Errors:  None
# - Finish writing to Partition  20240405
# - Check: insert 2291 rows.
# - Execution:  2024-04-06  Partition:  20240406
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1928f0>
#    Errors:  None
# - Finish writing to Partition  20240406
# - Check: insert 3813 rows.
# - Execution:  2024-04-07  Partition:  20240407
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8580>
#    Errors:  None
# - Finish writing to Partition  20240407
# - Check: insert 3719 rows.
# - Execution:  2024-04-08  Partition:  20240408
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4853c0>
#    Errors:  None
# - Finish writing to Partition  20240408
# - Check: insert 2895 rows.
# - Execution:  2024-04-09  Partition:  20240409
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f9120>
#    Errors:  None
# - Finish writing to Partition  20240409
# - Check: insert 2875 rows.
# - Execution:  2024-04-10  Partition:  20240410
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d870>
#    Errors:  None
# - Finish writing to Partition  20240410
# - Check: insert 2817 rows.
# - Execution:  2024-04-11  Partition:  20240411
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cad3f0>
#    Errors:  None
# - Finish writing to Partition  20240411
# - Check: insert 2752 rows.
# - Execution:  2024-04-12  Partition:  20240412
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8460>
#    Errors:  None
# - Finish writing to Partition  20240412
# - Check: insert 2877 rows.
# - Execution:  2024-04-13  Partition:  20240413
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca4f70>
#    Errors:  None
# - Finish writing to Partition  20240413
# - Check: insert 3946 rows.
# - Execution:  2024-04-14  Partition:  20240414
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c3d0>
#    Errors:  None
# - Finish writing to Partition  20240414
# - Check: insert 3928 rows.
# - Execution:  2024-04-15  Partition:  20240415
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f9750>
#    Errors:  None
# - Finish writing to Partition  20240415
# - Check: insert 2816 rows.
# - Execution:  2024-04-16  Partition:  20240416
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739cae080>
#    Errors:  None
# - Finish writing to Partition  20240416
# - Check: insert 2314 rows.
# - Execution:  2024-04-17  Partition:  20240417
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca49d0>
#    Errors:  None
# - Finish writing to Partition  20240417
# - Check: insert 2285 rows.
# - Execution:  2024-04-18  Partition:  20240418
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4853c0>
#    Errors:  None
# - Finish writing to Partition  20240418
# - Check: insert 2258 rows.
# - Execution:  2024-04-19  Partition:  20240419
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e299f0>
#    Errors:  None
# - Finish writing to Partition  20240419
# - Check: insert 2431 rows.
# - Execution:  2024-04-20  Partition:  20240420
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4fbee0>
#    Errors:  None
# - Finish writing to Partition  20240420
# - Check: insert 3946 rows.
# - Execution:  2024-04-21  Partition:  20240421
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e29900>
#    Errors:  None
# - Finish writing to Partition  20240421
# - Check: insert 3950 rows.
# - Execution:  2024-04-22  Partition:  20240422
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e65570>
#    Errors:  None
# - Finish writing to Partition  20240422
# - Check: insert 2626 rows.
# - Execution:  2024-04-23  Partition:  20240423
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739feebf0>
#    Errors:  None
# - Finish writing to Partition  20240423
# - Check: insert 2599 rows.
# - Execution:  2024-04-24  Partition:  20240424
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14fd30>
#    Errors:  None
# - Finish writing to Partition  20240424
# - Check: insert 2486 rows.
# - Execution:  2024-04-25  Partition:  20240425
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e674c0>
#    Errors:  None
# - Finish writing to Partition  20240425
# - Check: insert 2445 rows.
# - Execution:  2024-04-26  Partition:  20240426
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c3d0>
#    Errors:  None
# - Finish writing to Partition  20240426
# - Check: insert 2754 rows.
# - Execution:  2024-04-27  Partition:  20240427
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c3d0>
#    Errors:  None
# - Finish writing to Partition  20240427
# - Check: insert 3959 rows.
# - Execution:  2024-04-28  Partition:  20240428
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79476dcab4f0>
#    Errors:  None
# - Finish writing to Partition  20240428
# - Check: insert 3728 rows.
# - Execution:  2024-04-29  Partition:  20240429
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0b520>
#    Errors:  None
# - Finish writing to Partition  20240429
# - Check: insert 2893 rows.
# - Execution:  2024-04-30  Partition:  20240430
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e652d0>
#    Errors:  None
# - Finish writing to Partition  20240430
# - Check: insert 2416 rows.
# - Execution:  2024-05-01  Partition:  20240501
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0dd50>
#    Errors:  None
# - Finish writing to Partition  20240501
# - Check: insert 2305 rows.
# - Execution:  2024-05-02  Partition:  20240502
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b549d20>
#    Errors:  None
# - Finish writing to Partition  20240502
# - Check: insert 2442 rows.
# - Execution:  2024-05-03  Partition:  20240503
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141ea0>
#    Errors:  None
# - Finish writing to Partition  20240503
# - Check: insert 2269 rows.
# - Execution:  2024-05-04  Partition:  20240504
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79476dcab4f0>
#    Errors:  None
# - Finish writing to Partition  20240504
# - Check: insert 3710 rows.
# - Execution:  2024-05-05  Partition:  20240505
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b54ace0>
#    Errors:  None
# - Finish writing to Partition  20240505
# - Check: insert 3245 rows.
# - Execution:  2024-05-06  Partition:  20240506
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143c70>
#    Errors:  None
# - Finish writing to Partition  20240506
# - Check: insert 2844 rows.
# - Execution:  2024-05-07  Partition:  20240507
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0dd50>
#    Errors:  None
# - Finish writing to Partition  20240507
# - Check: insert 2454 rows.
# - Execution:  2024-05-08  Partition:  20240508
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b548850>
#    Errors:  None
# - Finish writing to Partition  20240508
# - Check: insert 2533 rows.
# - Execution:  2024-05-09  Partition:  20240509
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9810>
#    Errors:  None
# - Finish writing to Partition  20240509
# - Check: insert 2380 rows.
# - Execution:  2024-05-10  Partition:  20240510
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142e00>
#    Errors:  None
# - Finish writing to Partition  20240510
# - Check: insert 2890 rows.
# - Execution:  2024-05-11  Partition:  20240511
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0afe0>
#    Errors:  None
# - Finish writing to Partition  20240511
# - Check: insert 3581 rows.
# - Execution:  2024-05-12  Partition:  20240512
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9750>
#    Errors:  None
# - Finish writing to Partition  20240512
# - Check: insert 3970 rows.
# - Execution:  2024-05-13  Partition:  20240513
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142230>
#    Errors:  None
# - Finish writing to Partition  20240513
# - Check: insert 2766 rows.
# - Execution:  2024-05-14  Partition:  20240514
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9ab0>
#    Errors:  None
# - Finish writing to Partition  20240514
# - Check: insert 2573 rows.
# - Execution:  2024-05-15  Partition:  20240515
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9570>
#    Errors:  None
# - Finish writing to Partition  20240515
# - Check: insert 2569 rows.
# - Execution:  2024-05-16  Partition:  20240516
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1404f0>
#    Errors:  None
# - Finish writing to Partition  20240516
# - Check: insert 2276 rows.
# - Execution:  2024-05-17  Partition:  20240517
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b549300>
#    Errors:  None
# - Finish writing to Partition  20240517
# - Check: insert 2836 rows.
# - Execution:  2024-05-18  Partition:  20240518
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14f040>
#    Errors:  None
# - Finish writing to Partition  20240518
# - Check: insert 3773 rows.
# - Execution:  2024-05-19  Partition:  20240519
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fed780>
#    Errors:  None
# - Finish writing to Partition  20240519
# - Check: insert 3308 rows.
# - Execution:  2024-05-20  Partition:  20240520
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f97b0>
#    Errors:  None
# - Finish writing to Partition  20240520
# - Check: insert 2755 rows.
# - Execution:  2024-05-21  Partition:  20240521
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a140ca0>
#    Errors:  None
# - Finish writing to Partition  20240521
# - Check: insert 2512 rows.
# - Execution:  2024-05-22  Partition:  20240522
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141270>
#    Errors:  None
# - Finish writing to Partition  20240522
# - Check: insert 2887 rows.
# - Execution:  2024-05-23  Partition:  20240523
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14ebc0>
#    Errors:  None
# - Finish writing to Partition  20240523
# - Check: insert 2329 rows.
# - Execution:  2024-05-24  Partition:  20240524
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9900>
#    Errors:  None
# - Finish writing to Partition  20240524
# - Check: insert 2325 rows.
# - Execution:  2024-05-25  Partition:  20240525
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14c0d0>
#    Errors:  None
# - Finish writing to Partition  20240525
# - Check: insert 3823 rows.
# - Execution:  2024-05-26  Partition:  20240526
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c3d0>
#    Errors:  None
# - Finish writing to Partition  20240526
# - Check: insert 3588 rows.
# - Execution:  2024-05-27  Partition:  20240527
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fef880>
#    Errors:  None
# - Finish writing to Partition  20240527
# - Check: insert 2590 rows.
# - Execution:  2024-05-28  Partition:  20240528
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739caf730>
#    Errors:  None
# - Finish writing to Partition  20240528
# - Check: insert 2858 rows.
# - Execution:  2024-05-29  Partition:  20240529
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14db40>
#    Errors:  None
# - Finish writing to Partition  20240529
# - Check: insert 2571 rows.
# - Execution:  2024-05-30  Partition:  20240530
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0fab60>
#    Errors:  None
# - Finish writing to Partition  20240530
# - Check: insert 2755 rows.
# - Execution:  2024-05-31  Partition:  20240531
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739feebf0>
#    Errors:  None
# - Finish writing to Partition  20240531
# - Check: insert 2964 rows.
# - Execution:  2024-06-01  Partition:  20240601
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e29ae0>
#    Errors:  None
# - Finish writing to Partition  20240601
# - Check: insert 3980 rows.
# - Execution:  2024-06-02  Partition:  20240602
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b548c70>
#    Errors:  None
# - Finish writing to Partition  20240602
# - Check: insert 3984 rows.
# - Execution:  2024-06-03  Partition:  20240603
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d870>
#    Errors:  None
# - Finish writing to Partition  20240603
# - Check: insert 2330 rows.
# - Execution:  2024-06-04  Partition:  20240604
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8fd0>
#    Errors:  None
# - Finish writing to Partition  20240604
# - Check: insert 2760 rows.
# - Execution:  2024-06-05  Partition:  20240605
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d720>
#    Errors:  None
# - Finish writing to Partition  20240605
# - Check: insert 2279 rows.
# - Execution:  2024-06-06  Partition:  20240606
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e2a740>
#    Errors:  None
# - Finish writing to Partition  20240606
# - Check: insert 2398 rows.
# - Execution:  2024-06-07  Partition:  20240607
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4fa110>
#    Errors:  None
# - Finish writing to Partition  20240607
# - Check: insert 2688 rows.
# - Execution:  2024-06-08  Partition:  20240608
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0fa9b0>
#    Errors:  None
# - Finish writing to Partition  20240608
# - Check: insert 3774 rows.
# - Execution:  2024-06-09  Partition:  20240609
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1412d0>
#    Errors:  None
# - Finish writing to Partition  20240609
# - Check: insert 3674 rows.
# - Execution:  2024-06-10  Partition:  20240610
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b549d20>
#    Errors:  None
# - Finish writing to Partition  20240610
# - Check: insert 2853 rows.
# - Execution:  2024-06-11  Partition:  20240611
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c190>
#    Errors:  None
# - Finish writing to Partition  20240611
# - Check: insert 2396 rows.
# - Execution:  2024-06-12  Partition:  20240612
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b548c70>
#    Errors:  None
# - Finish writing to Partition  20240612
# - Check: insert 2875 rows.
# - Execution:  2024-06-13  Partition:  20240613
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0fa4a0>
#    Errors:  None
# - Finish writing to Partition  20240613
# - Check: insert 2644 rows.
# - Execution:  2024-06-14  Partition:  20240614
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0c9d0>
#    Errors:  None
# - Finish writing to Partition  20240614
# - Check: insert 2861 rows.
# - Execution:  2024-06-15  Partition:  20240615
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0f9a0>
#    Errors:  None
# - Finish writing to Partition  20240615
# - Check: insert 3893 rows.
# - Execution:  2024-06-16  Partition:  20240616
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e67eb0>
#    Errors:  None
# - Finish writing to Partition  20240616
# - Check: insert 3841 rows.
# - Execution:  2024-06-17  Partition:  20240617
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b54b400>
#    Errors:  None
# - Finish writing to Partition  20240617
# - Check: insert 2651 rows.
# - Execution:  2024-06-18  Partition:  20240618
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739feeb60>
#    Errors:  None
# - Finish writing to Partition  20240618
# - Check: insert 2860 rows.
# - Execution:  2024-06-19  Partition:  20240619
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d08fd0>
#    Errors:  None
# - Finish writing to Partition  20240619
# - Check: insert 2331 rows.
# - Execution:  2024-06-20  Partition:  20240620
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9d80>
#    Errors:  None
# - Finish writing to Partition  20240620
# - Check: insert 2294 rows.
# - Execution:  2024-06-21  Partition:  20240621
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0e2c0>
#    Errors:  None
# - Finish writing to Partition  20240621
# - Check: insert 2411 rows.
# - Execution:  2024-06-22  Partition:  20240622
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b486ce0>
#    Errors:  None
# - Finish writing to Partition  20240622
# - Check: insert 3834 rows.
# - Execution:  2024-06-23  Partition:  20240623
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e2b3a0>
#    Errors:  None
# - Finish writing to Partition  20240623
# - Check: insert 3780 rows.
# - Execution:  2024-06-24  Partition:  20240624
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f9d80>
#    Errors:  None
# - Finish writing to Partition  20240624
# - Check: insert 2539 rows.
# - Execution:  2024-06-25  Partition:  20240625
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28700>
#    Errors:  None
# - Finish writing to Partition  20240625
# - Check: insert 2609 rows.
# - Execution:  2024-06-26  Partition:  20240626
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d660>
#    Errors:  None
# - Finish writing to Partition  20240626
# - Check: insert 2289 rows.
# - Execution:  2024-06-27  Partition:  20240627
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d870>
#    Errors:  None
# - Finish writing to Partition  20240627
# - Check: insert 2366 rows.
# - Execution:  2024-06-28  Partition:  20240628
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b54bb20>
#    Errors:  None
# - Finish writing to Partition  20240628
# - Check: insert 2749 rows.
# - Execution:  2024-06-29  Partition:  20240629
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e299f0>
#    Errors:  None
# - Finish writing to Partition  20240629
# - Check: insert 3851 rows.
# - Execution:  2024-06-30  Partition:  20240630
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e28bb0>
#    Errors:  None
# - Finish writing to Partition  20240630
# - Check: insert 3950 rows.
# - Execution:  2024-07-01  Partition:  20240701
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739fee680>
#    Errors:  None
# - Finish writing to Partition  20240701
# - Check: insert 2429 rows.
# ...
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866f880>
#    Errors:  None
# - Finish writing to Partition  20250225
# - Check: insert 2559 rows.
# - Execution:  2025-02-26  Partition:  20250226
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866f4c0>
#    Errors:  None
# - Finish writing to Partition  20250226
# - Check: insert 2852 rows.
# - Execution:  2025-02-27  Partition:  20250227
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x7947384952a0>
#    Errors:  None
# - Finish writing to Partition  20250227
# - Check: insert 2272 rows.
# - Execution:  2025-02-28  Partition:  20250228
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a1421d0>
#    Errors:  None
# - Finish writing to Partition  20250228
# - Check: insert 2791 rows.
# - Execution:  2025-03-01  Partition:  20250301
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d0ae60>
#    Errors:  None
# - Finish writing to Partition  20250301
# - Check: insert 3493 rows.
# - Execution:  2025-03-02  Partition:  20250302
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143a30>
#    Errors:  None
# - Finish writing to Partition  20250302
# - Check: insert 3284 rows.
# - Execution:  2025-03-03  Partition:  20250303
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739d08fd0>
#    Errors:  None
# - Finish writing to Partition  20250303
# - Check: insert 2600 rows.
# - Execution:  2025-03-04  Partition:  20250304
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e64a90>
#    Errors:  None
# - Finish writing to Partition  20250304
# - Check: insert 2507 rows.
# - Execution:  2025-03-05  Partition:  20250305
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b54a3e0>
#    Errors:  None
# - Finish writing to Partition  20250305
# - Check: insert 2706 rows.
# - Execution:  2025-03-06  Partition:  20250306
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0f95a0>
#    Errors:  None
# - Finish writing to Partition  20250306
# - Check: insert 2575 rows.
# - Execution:  2025-03-07  Partition:  20250307
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141330>
#    Errors:  None
# - Finish writing to Partition  20250307
# - Check: insert 2677 rows.
# - Execution:  2025-03-08  Partition:  20250308
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e282b0>
#    Errors:  None
# - Finish writing to Partition  20250308
# - Check: insert 3734 rows.
# - Execution:  2025-03-09  Partition:  20250309
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a142ce0>
#    Errors:  None
# - Finish writing to Partition  20250309
# - Check: insert 3702 rows.
# - Execution:  2025-03-10  Partition:  20250310
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739feeb60>
#    Errors:  None
# - Finish writing to Partition  20250310
# - Check: insert 2464 rows.
# - Execution:  2025-03-11  Partition:  20250311
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141330>
#    Errors:  None
# - Finish writing to Partition  20250311
# - Check: insert 2314 rows.
# - Execution:  2025-03-12  Partition:  20250312
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b5488e0>
#    Errors:  None
# - Finish writing to Partition  20250312
# - Check: insert 2481 rows.
# - Execution:  2025-03-13  Partition:  20250313
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866ffd0>
#    Errors:  None
# - Finish writing to Partition  20250313
# - Check: insert 2464 rows.
# - Execution:  2025-03-14  Partition:  20250314
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866fd30>
#    Errors:  None
# - Finish writing to Partition  20250314
# - Check: insert 2453 rows.
# - Execution:  2025-03-15  Partition:  20250315
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0feda0>
#    Errors:  None
# - Finish writing to Partition  20250315
# - Check: insert 3923 rows.
# - Execution:  2025-03-16  Partition:  20250316
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866d360>
#    Errors:  None
# - Finish writing to Partition  20250316
# - Check: insert 3911 rows.
# - Execution:  2025-03-17  Partition:  20250317
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0feda0>
#    Errors:  None
# - Finish writing to Partition  20250317
# - Check: insert 2769 rows.
# - Execution:  2025-03-18  Partition:  20250318
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494910>
#    Errors:  None
# - Finish writing to Partition  20250318
# - Check: insert 2852 rows.
# - Execution:  2025-03-19  Partition:  20250319
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b54b5b0>
#    Errors:  None
# - Finish writing to Partition  20250319
# - Check: insert 2755 rows.
# - Execution:  2025-03-20  Partition:  20250320
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495c60>
#    Errors:  None
# - Finish writing to Partition  20250320
# - Check: insert 2754 rows.
# - Execution:  2025-03-21  Partition:  20250321
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141540>
#    Errors:  None
# - Finish writing to Partition  20250321
# - Check: insert 2618 rows.
# - Execution:  2025-03-22  Partition:  20250322
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495480>
#    Errors:  None
# - Finish writing to Partition  20250322
# - Check: insert 3392 rows.
# - Execution:  2025-03-23  Partition:  20250323
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495900>
#    Errors:  None
# - Finish writing to Partition  20250323
# - Check: insert 3803 rows.
# - Execution:  2025-03-24  Partition:  20250324
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494a90>
#    Errors:  None
# - Finish writing to Partition  20250324
# - Check: insert 2671 rows.
# - Execution:  2025-03-25  Partition:  20250325
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495330>
#    Errors:  None
# - Finish writing to Partition  20250325
# - Check: insert 2775 rows.
# - Execution:  2025-03-26  Partition:  20250326
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494130>
#    Errors:  None
# - Finish writing to Partition  20250326
# - Check: insert 2696 rows.
# - Execution:  2025-03-27  Partition:  20250327
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494700>
#    Errors:  None
# - Finish writing to Partition  20250327
# - Check: insert 2476 rows.
# - Execution:  2025-03-28  Partition:  20250328
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494490>
#    Errors:  None
# - Finish writing to Partition  20250328
# - Check: insert 2416 rows.
# - Execution:  2025-03-29  Partition:  20250329
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738496470>
#    Errors:  None
# - Finish writing to Partition  20250329
# - Check: insert 3900 rows.
# - Execution:  2025-03-30  Partition:  20250330
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495c60>
#    Errors:  None
# - Finish writing to Partition  20250330
# - Check: insert 3912 rows.
# - Execution:  2025-03-31  Partition:  20250331
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738494130>
#    Errors:  None
# - Finish writing to Partition  20250331
# - Check: insert 2655 rows.
# - Execution:  2025-04-01  Partition:  20250401
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495d20>
#    Errors:  None
# - Finish writing to Partition  20250401
# - Check: insert 2510 rows.
# - Execution:  2025-04-02  Partition:  20250402
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738496b60>
#    Errors:  None
# - Finish writing to Partition  20250402
# - Check: insert 2741 rows.
# - Execution:  2025-04-03  Partition:  20250403
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738497a30>
#    Errors:  None
# - Finish writing to Partition  20250403
# - Check: insert 2526 rows.
# - Execution:  2025-04-04  Partition:  20250404
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738495870>
#    Errors:  None
# - Finish writing to Partition  20250404
# - Check: insert 2786 rows.
# - Execution:  2025-04-05  Partition:  20250405
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794738497640>
#    Errors:  None
# - Finish writing to Partition  20250405
# - Check: insert 3844 rows.
# - Execution:  2025-04-06  Partition:  20250406
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0fa530>
#    Errors:  None
# - Finish writing to Partition  20250406
# - Check: insert 3840 rows.
# - Execution:  2025-04-07  Partition:  20250407
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b486ce0>
#    Errors:  None
# - Finish writing to Partition  20250407
# - Check: insert 2308 rows.
# - Execution:  2025-04-08  Partition:  20250408
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a0fa170>
#    Errors:  None
# - Finish writing to Partition  20250408
# - Check: insert 2911 rows.
# - Execution:  2025-04-09  Partition:  20250409
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866fe80>
#    Errors:  None
# - Finish writing to Partition  20250409
# - Check: insert 2871 rows.
# - Execution:  2025-04-10  Partition:  20250410
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca66e0>
#    Errors:  None
# - Finish writing to Partition  20250410
# - Check: insert 2439 rows.
# - Execution:  2025-04-11  Partition:  20250411
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a141330>
#    Errors:  None
# - Finish writing to Partition  20250411
# - Check: insert 2774 rows.
# - Execution:  2025-04-12  Partition:  20250412
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866d360>
#    Errors:  None
# - Finish writing to Partition  20250412
# - Check: insert 3959 rows.
# - Execution:  2025-04-13  Partition:  20250413
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e64460>
#    Errors:  None
# - Finish writing to Partition  20250413
# - Check: insert 3227 rows.
# - Execution:  2025-04-14  Partition:  20250414
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0d630>
#    Errors:  None
# - Finish writing to Partition  20250414
# - Check: insert 2387 rows.
# - Execution:  2025-04-15  Partition:  20250415
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866f910>
#    Errors:  None
# - Finish writing to Partition  20250415
# - Check: insert 2742 rows.
# - Execution:  2025-04-16  Partition:  20250416
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e0fbe0>
#    Errors:  None
# - Finish writing to Partition  20250416
# - Check: insert 2269 rows.
# - Execution:  2025-04-17  Partition:  20250417
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8070>
#    Errors:  None
# - Finish writing to Partition  20250417
# - Check: insert 2334 rows.
# - Execution:  2025-04-18  Partition:  20250418
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473b4f8070>
#    Errors:  None
# - Finish writing to Partition  20250418
# - Check: insert 3916 rows.
# - Execution:  2025-04-19  Partition:  20250419
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e674c0>
#    Errors:  None
# - Finish writing to Partition  20250419
# - Check: insert 3818 rows.
# - Execution:  2025-04-20  Partition:  20250420
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739e64a90>
#    Errors:  None
# - Finish writing to Partition  20250420
# - Check: insert 3821 rows.
# - Execution:  2025-04-21  Partition:  20250421
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866f430>
#    Errors:  None
# - Finish writing to Partition  20250421
# - Check: insert 2669 rows.
# - Execution:  2025-04-22  Partition:  20250422
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x794739ca4fa0>
#    Errors:  None
# - Finish writing to Partition  20250422
# - Check: insert 2522 rows.
# - Execution:  2025-04-23  Partition:  20250423
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a143970>
#    Errors:  None
# - Finish writing to Partition  20250423
# - Check: insert 2872 rows.
# - Execution:  2025-04-24  Partition:  20250424
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473866df00>
#    Errors:  None
# - Finish writing to Partition  20250424
# - Check: insert 2886 rows.
# - Execution:  2025-04-25  Partition:  20250425
#     Table dws_campaign_cost_sale_prd_d_inc already exists.
#    Result: <google.cloud.bigquery.table.RowIterator object at 0x79473a14dff0>
#    Errors:  None
# - Finish writing to Partition  20250425
# - Check: insert 2445 rows.

# %% [markdown]
# ### Insert Summary

# %%
total_row_cnt_df
# Out:
#           date  row_cnt
# 0   2024-01-01     2570
# 1   2024-01-02     2556
# 2   2024-01-03     2240
# 3   2024-01-04     2700
# 4   2024-01-05     2742
# 5   2024-01-06     3622
# 6   2024-01-07     3891
# 7   2024-01-08     2581
# 8   2024-01-09     2906
# 9   2024-01-10     2602
# 10  2024-01-11     2655
# 11  2024-01-12     2541
# 12  2024-01-13     3818
# 13  2024-01-14     3302
# 14  2024-01-15     2349
# 15  2024-01-16     2559
# 16  2024-01-17     2701
# 17  2024-01-18     2638
# 18  2024-01-19     2426
# 19  2024-01-20     3825
